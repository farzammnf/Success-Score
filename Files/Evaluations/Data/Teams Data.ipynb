# %%
import soccerdata as sd
import pandas as pd
# Out:
# [12/05/24 14:19:39] INFO     No custom team name replacements found. You can configure these in       ]8;id=539316;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=655696;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/_config.py#87\87]8;;\
#                              /Users/farzammanafzadeh/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=276407;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=284785;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/_config.py#182\182]8;;\
#                              /Users/farzammanafzadeh/soccerdata/config/league_dict.json.

# %%
sofifa = sd.SoFIFA(leagues=['ENG-Premier League',
 'ESP-La Liga',
 'FRA-Ligue 1',
 'GER-Bundesliga',
 'ITA-Serie A'], versions="latest")
print(sofifa.__doc__)
# Out:
#                     INFO     Saving cached data to /Users/farzammanafzadeh/soccerdata/data/SoFIFA     ]8;id=676145;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=195357;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/_common.py#92\92]8;;\
# Provides pd.DataFrames from data at http://sofifa.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/SoFIFA``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include.
#     versions : string, int or list of int, optional
#         FIFA releases to include. Should be specified by their ID used in the URL
#         (e.g., 230034). Alternatively, the string "all" can be used to include all
#         versions and "latest" to include the latest version only. Defaults to
#         "latest".
#     proxy : 'tor' or dict or list(dict) or callable, optional
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
team_ratings = sofifa.read_team_ratings()
team_ratings.head()
# Out:
# [10/14/24 19:41:24] INFO     [1/5] Retrieving teams for ENG-Premier League in Oct 8, 2024 edition     ]8;id=110057;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/sofifa.py\sofifa.py]8;;\:]8;id=730204;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/sofifa.py#346\346]8;;\
#                     INFO     [2/5] Retrieving teams for ESP-La Liga in Oct 8, 2024 edition            ]8;id=374434;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/sofifa.py\sofifa.py]8;;\:]8;id=287485;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/sofifa.py#346\346]8;;\
#                     INFO     [3/5] Retrieving teams for FRA-Ligue 1 in Oct 8, 2024 edition            ]8;id=333431;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/sofifa.py\sofifa.py]8;;\:]8;id=555920;file:///opt/anaconda3/lib/python3.11/site-packages/soccerdata/sofifa.py#346\346]8;;\
# ...

# %%
team_ratings.to_csv('team_ratings.csv', header=True)

# %%
df = pd.read_csv('team_ratings.csv')

# %%
df.head()
# Out:
#                league                    team  overall  attack  midfield  \
# 0  ENG-Premier League         AFC Bournemouth       76      79        76
# 1  ENG-Premier League                 Arsenal       84      82        85
# 2  ENG-Premier League             Aston Villa       80      85        79
# 3  ENG-Premier League               Brentford       76      77        74
# 4  ENG-Premier League  Brighton & Hove Albion       77      76        76
#
#    defence transfer_budget club_worth build_up_speed build_up_dribbling  \
# 0       76              €0      €410M           Slow             Little
# 1       84              €0      €1.9B           Slow             Little
# 2       80              €0      €800M           Slow             Little
# 3       76              €0      €430M           Slow             Little
# 4       77              €0      €675M           Slow             Little
#
#   build_up_passing build_up_positioning chance_creation_crossing  \
# ...

# %%
columns_to_drop = ['build_up_speed', 'build_up_dribbling', 'build_up_passing', 'build_up_positioning', 'chance_creation_crossing', 'chance_creation_passing', 'chance_creation_shooting', 'chance_creation_positioning', 'defence_aggression', 'defence_pressure', 'defence_team_width', 'defence_defender_line',"transfer_budget"]
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#                league                    team  overall  attack  midfield  \
# 0  ENG-Premier League         AFC Bournemouth       76      79        76
# 1  ENG-Premier League                 Arsenal       84      82        85
# 2  ENG-Premier League             Aston Villa       80      85        79
# 3  ENG-Premier League               Brentford       76      77        74
# 4  ENG-Premier League  Brighton & Hove Albion       77      76        76
#
#    defence club_worth  defence_domestic_prestige  international_prestige  \
# 0       76      €410M                          2                       2
# 1       84      €1.9B                          9                       9
# 2       80      €800M                          7                       6
# 3       76      €430M                          3                       2
# 4       77      €675M                          5                       5
#
#    players  starting_xi_average_age  whole_team_average_age fifa_edition  \
# ...

# %%
df.to_csv('team_ratings.csv')
