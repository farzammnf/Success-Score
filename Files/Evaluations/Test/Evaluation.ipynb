# %%
# Evaluation : In this Notebook we predict match outcomes and also introducing Success Score's applications.

# %%
import pandas as pd
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('Evaluation.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
data.head()
# Out:
#            league  season            home_team                 away_team  home_score  away_score  \
# 0  GER-Bundesliga    2324        Werder Bremen         FC Bayern München           0           4
# 1  GER-Bundesliga    2324          FC Augsburg  Borussia Mönchengladbach           4           4
# 2  GER-Bundesliga    2324  Bayer 04 Leverkusen                RB Leipzig           3           2
# 3  GER-Bundesliga    2324    Borussia Dortmund                   FC Köln           1           0
# 4  GER-Bundesliga    2324       TSG Hoffenheim               Freiburg II           1           2
#
#    home_overall  home_attack  home_midfield  home_defence  home_international_prestige  \
# 0          74.0         75.0           74.0          74.0                          3.0
# 1          74.0         72.0           74.0          74.0                          3.0
# 2          80.0         81.0           81.0          79.0                          6.0
# ...

# %%
data["league"].unique()
# Out:
# array(['GER-Bundesliga', 'ITA-Serie A', 'ESP-La Liga',
#        'ENG-Premier League'], dtype=object)

# %%
# data = data[data["league"] == "ENG-Premier League"]

# %%
data.head()
# Out:
#            league  season            home_team                 away_team  home_score  away_score  \
# 0  GER-Bundesliga    2324        Werder Bremen         FC Bayern München           0           4
# 1  GER-Bundesliga    2324          FC Augsburg  Borussia Mönchengladbach           4           4
# 2  GER-Bundesliga    2324  Bayer 04 Leverkusen                RB Leipzig           3           2
# 3  GER-Bundesliga    2324    Borussia Dortmund                   FC Köln           1           0
# 4  GER-Bundesliga    2324       TSG Hoffenheim               Freiburg II           1           2
#
#    home_overall  home_attack  home_midfield  home_defence  home_international_prestige  \
# 0          74.0         75.0           74.0          74.0                          3.0
# 1          74.0         72.0           74.0          74.0                          3.0
# 2          80.0         81.0           81.0          79.0                          6.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1437 entries, 0 to 1436
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   league                       1437 non-null   object
#  1   season                       1437 non-null   int64
#  2   home_team                    1437 non-null   object
#  3   away_team                    1437 non-null   object
#  4   home_score                   1437 non-null   int64
#  5   away_score                   1437 non-null   int64
#  6   home_overall                 1437 non-null   float64
#  7   home_attack                  1437 non-null   float64
#  8   home_midfield                1437 non-null   float64
#  9   home_defence                 1437 non-null   float64
#  10  home_international_prestige  1437 non-null   float64
#  11  home_domestic_prestige       1437 non-null   float64
#  12  home_possession_play         1437 non-null   int64
# ...

# %%
data.count()
# Out:
# league                         1437
# season                         1437
# home_team                      1437
# away_team                      1437
# home_score                     1437
# away_score                     1437
# home_overall                   1437
# home_attack                    1437
# home_midfield                  1437
# home_defence                   1437
# home_international_prestige    1437
# home_domestic_prestige         1437
# home_possession_play           1437
# home_counter_attack            1437
# home_high_press                1437
# home_direct_play               1437
# home_wing_play                 1437
# home_set_piece_focus           1437
# home_creative_playmaking       1437
# home_playing_out_back          1437
# home_low_block                 1437
# home_high_defensive_line       1437
# away_overall                   1437
# away_attack                    1437
# away_midfield                  1437
# away_defence                   1437
# ...

# %%
df = data

# %%
team_averages_df = df

# %%
teams_rating = pd.read_csv('team_ratings.csv')
teams_rating.head()
# Out:
#    Unnamed: 0              league                    team  overall  attack  midfield  defence  \
# 0           0  ENG-Premier League         AFC Bournemouth       76      79        76       76
# 1           1  ENG-Premier League                 Arsenal       84      82        85       84
# 2           2  ENG-Premier League             Aston Villa       80      85        79       80
# 3           3  ENG-Premier League               Brentford       76      77        74       76
# 4           4  ENG-Premier League  Brighton & Hove Albion       77      76        76       77
#
#   club_worth  defence_domestic_prestige  international_prestige  players  starting_xi_average_age  \
# 0      €410M                          2                       2       25                    24.82
# 1      €1.9B                          9                       9       24                    25.55
# 2      €800M                          7                       6       25                    26.64
# ...

# %%
games = pd.read_csv('2024-2025.csv')

# %%
data = games

# %%
import pandas as pd

# Possession Play
data['home_possession_play'] = (
    data["home_xG open play"] * 0.2 +
    data['home_Ball possession'] * 0.2 +
    data['home_Accurate passes'] * 0.2 +
    data['home_Passes'] * 0.2 +
    data['home_Accurate passes (%)'] * 0.2 +
    data['home_Own half'] * 0.2
)

data['away_possession_play'] = (
    data["away_xG open play"] * 0.2 +
    data['away_Ball possession'] * 0.2 +
    data['away_Accurate passes'] * 0.2 +
    data['away_Passes'] * 0.2 +
    data['away_Accurate passes (%)'] * 0.2 +
    data['away_Own half'] * 0.2 
)

# Counter-Attack
data['home_counter_attack'] = (
    data['away_Ball possession'] * 0.2 +
    data['home_Big chances'] / data["home_Total shots"] * 0.2 +
    data['home_Accurate long balls'] * 0.2 +
    data['home_Opposition half'] * 0.2 +
    data['home_Offsides'] * 0.2 +
    data["home_Shots inside box"] * 0.2 +  
    data["home_Shots on target"] / data["home_Total shots"] * 0.2
)

data['away_counter_attack'] = (
    data['home_Ball possession'] * 0.2 +
    data['away_Big chances'] / data["away_Total shots"] * 0.2 +
    data['away_Accurate long balls'] * 0.2 +
    data['away_Opposition half'] * 0.2 +
    data['away_Offsides'] * 0.2 +
    data["away_Shots inside box"] * 0.2 + 
    data["away_Shots on target"] / data["away_Total shots"] * 0.2
)

# High Press
data['home_high_press'] = (
    data['home_Fouls committed'] * 0.2 +
    data['home_Opposition half'] * 0.2 +
    data['home_Shots inside box'] * 0.2 +
    data['home_Corners'] * 0.2 +
    (data["home_Throws"] + data["away_Throws"]) * 0.2  
)

data['away_high_press'] = (
    data['away_Fouls committed'] * 0.2 +
    data['away_Opposition half'] * 0.2 +
    data['away_Shots inside box'] * 0.2 +
    data['away_Corners'] * 0.2 +
    (data["home_Throws"] + data["away_Throws"]) * 0.2  
)

# Direct Play
data['home_direct_play'] = (
    data['home_Accurate long balls'] * 0.3 +
    data['home_Shots inside box'] * 0.25 +
    data['home_Big chances'] * 0.25 +
    data['home_Offsides'] * 0.2
)

data['away_direct_play'] = (
    data['away_Accurate long balls'] * 0.3 +
    data['away_Shots inside box'] * 0.25 +
    data['away_Big chances'] * 0.25 +
    data['away_Offsides'] * 0.2
)

# Wing Play
data['home_wing_play'] = (
    data['home_Accurate crosses'] * 0.4 +
    data['home_Shots inside box'] * 0.3 +
    data['home_Corners'] * 0.2 +
    (data["home_Throws"] + data["away_Throws"]) * 0.1  
)

data['away_wing_play'] = (
    data['away_Accurate crosses'] * 0.4 +
    data['away_Shots inside box'] * 0.3 +
    data['away_Corners'] * 0.2 +
    (data["home_Throws"] + data["away_Throws"]) * 0.1  
)

# Set Piece Focus
data['home_set_piece_focus'] = (
    data['home_xG set play'] * 0.3 +
    data['home_Corners'] * 0.3 +
    data['home_Accurate crosses'] * 0.2 
)

data['away_set_piece_focus'] = (
    data['away_xG set play'] * 0.3 +
    data['away_Corners'] * 0.3 +
    data['away_Accurate crosses'] * 0.2 
)

# Creative Playmaking
data['home_creative_playmaking'] = (
    data['home_Accurate passes (%)'] * 0.3 +
    data['home_Big chances'] * 0.3 +
    data['home_Accurate long balls'] * 0.2 +
    data['home_Opposition half'] * 0.2
)

data['away_creative_playmaking'] = (
    data['away_Accurate passes (%)'] * 0.3 +
    data['away_Big chances'] * 0.3 +
    data['away_Accurate long balls'] * 0.2 +
    data['away_Opposition half'] * 0.2
)

# Playing Out from the Back
data['home_playing_out_back'] = (
    data['home_Own half'] * 0.4 +
    data['home_Accurate passes'] * 0.3 +
    data['home_Accurate long balls'] * 0.3
)

data['away_playing_out_back'] = (
    data['away_Own half'] * 0.4 +
    data['away_Accurate passes'] * 0.3 +
    data['away_Accurate long balls'] * 0.3
)

# Low Block 
data['home_low_block'] = (
    data['home_Blocked shots'] * 0.4 +
    data['home_Own half'] * 0.4 +
    data['home_Fouls committed'] * 0.2 +
    data["away_Shots outside box"] * 0.2
)

data['away_low_block'] = (
    data['away_Blocked shots'] * 0.25 +
    data['away_Own half'] * 0.25 +
    data['away_Fouls committed'] * 0.25 +
    data["home_Shots outside box"] * 0.25
)

# High Defensive Line
data['home_high_defensive_line'] = (
    data['away_Offsides'] * 0.25 +
    data['home_Opposition half'] * 0.25 +
    data['home_Fouls committed'] * 0.25 +
    data["away_Shots inside box"] * 0.25
)

data['away_high_defensive_line'] = (
    data['home_Offsides'] * 0.25 +
    data['away_Opposition half'] * 0.25 +
    data['away_Fouls committed'] * 0.25 +
    data["away_Shots inside box"] * 0.25
)

tactics_columns = [
    'possession_play', 'counter_attack', 'high_press', 'direct_play',
    'wing_play', 'set_piece_focus', 'creative_playmaking', 'playing_out_back', 
    'low_block', 'high_defensive_line',
]

# %%
data.dropna(inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0              league  season                                        game  round  \
# 0           0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1
# 1           1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1
# 2           2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1
# 3           3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1
# 4           4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1
#
#    week                       date          home_team                away_team  home_score  \
# 0     1  2024-08-16 19:00:00+00:00  Manchester United                   Fulham         1.0
# 1     1  2024-08-17 14:00:00+00:00            Arsenal  Wolverhampton Wanderers         2.0
# 2     1  2024-08-17 14:00:00+00:00            Everton   Brighton & Hove Albion         0.0
# ...

# %%
data["home_Expected goals (xG)"].count()
# Out:
# 430

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 430 entries, 0 to 1461
# Data columns (total 94 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      430 non-null    int64
#  1   league                          430 non-null    object
#  2   season                          430 non-null    int64
#  3   game                            430 non-null    object
#  4   round                           430 non-null    int64
#  5   week                            430 non-null    int64
#  6   date                            430 non-null    object
#  7   home_team                       430 non-null    object
#  8   away_team                       430 non-null    object
#  9   home_score                      430 non-null    float64
#  10  away_score                      430 non-null    float64
#  11  status                          430 non-null    object
# ...

# %%
import numpy as np

# %%
def sigmoid(x, k=1, x0=1.5):
    """
    Apply the sigmoid function to a value.
    - x: the input value (e.g., a metric).
    - k: steepness of the curve.
    - x0: midpoint around which the curve transitions.
    """
    return 1 / (1 + np.exp(-k * (x - x0)))

def calculate_success_scores_adjusted(row):
    """
    Calculate the success scores for home and away teams using adjusted sigmoid scaling.
    - row: a row of the DataFrame containing home/away scores and xG.
    Returns:
    - (home_success_score, away_success_score): Success scores normalized to sum to 10.
    """
    # Extract relevant data
    home_score = row['home_score']
    away_score = row['away_score']
    home_xG = row['home_Expected goals (xG)']
    away_xG = row['away_Expected goals (xG)']

    # Calculate combined metrics
    home_metric = home_score + home_xG
    away_metric = away_score + away_xG

    # Add a base score to prevent dramatic differences
    base_score = 0.5  # Minimum contribution for each team
    home_metric += base_score
    away_metric += base_score

    # Apply sigmoid scaling
    k = 0.8  # Reduced steepness for smoother transitions
    x0 = 2   # Midpoint adjusted for your data range
    home_scaled = sigmoid(home_metric, k, x0)
    away_scaled = sigmoid(away_metric, k, x0)

    # Normalize to sum to 10
    total_scaled = home_scaled + away_scaled
    home_success_score = (home_scaled / total_scaled) * 10
    away_success_score = (away_scaled / total_scaled) * 10

    # Return rounded scores
    return round(home_success_score, 2), round(away_success_score, 2)


# Apply the adjusted scoring function
data['home_success_score'], data['away_success_score'] = zip(*data.apply(calculate_success_scores_adjusted, axis=1))

data.head()
# Out:
#    Unnamed: 0              league  season                                        game  round  \
# 0           0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1
# 1           1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1
# 2           2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1
# 3           3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1
# 4           4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1
#
#    week                       date          home_team                away_team  home_score  \
# 0     1  2024-08-16 19:00:00+00:00  Manchester United                   Fulham         1.0
# 1     1  2024-08-17 14:00:00+00:00            Arsenal  Wolverhampton Wanderers         2.0
# 2     1  2024-08-17 14:00:00+00:00            Everton   Brighton & Hove Albion         0.0
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
import pandas as pd

df = games

# Select the specific columns

selected_columns = ['league', 'season', 'game', 'round', 'week', 'date', 'home_team', 'away_team', 'home_score', 'away_score', 'status','home_possession_play', 'away_possession_play', 'home_counter_attack', 'away_counter_attack', 'home_high_press', 'away_high_press', 'home_direct_play', 'away_direct_play', 'home_wing_play', 'away_wing_play', 'home_set_piece_focus', 'away_set_piece_focus', 'home_creative_playmaking', 'away_creative_playmaking', 'home_playing_out_back', 'away_playing_out_back', 'home_low_block', 'away_low_block', 'home_high_defensive_line', 'away_high_defensive_line', 'home_success_score', 'away_success_score']
extracted_df = df[selected_columns]

# Display the result
extracted_df.head()
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
#
#                         date          home_team                away_team  home_score  away_score  \
# 0  2024-08-16 19:00:00+00:00  Manchester United                   Fulham         1.0         0.0
# 1  2024-08-17 14:00:00+00:00            Arsenal  Wolverhampton Wanderers         2.0         0.0
# 2  2024-08-17 14:00:00+00:00            Everton   Brighton & Hove Albion         0.0         3.0
# ...

# %%
teams_rating_df = teams_rating

# %%
teams_rating_df["team"].unique()
# Out:
# array(['AFC Bournemouth', 'Arsenal', 'Aston Villa', 'Brentford',
#        'Brighton & Hove Albion', 'Chelsea', 'Crystal Palace', 'Everton',
#        'Fulham', 'Ipswich Town', 'Leicester City', 'Liverpool',
#        'Manchester City', 'Manchester United', 'Newcastle United',
#        'Nottingham Forest', 'Southampton', 'Tottenham Hotspur',
#        'West Ham United', 'Wolverhampton Wanderers', 'Athletic Club',
#        'Atlético Madrid', 'Celta de Vigo', 'Deportivo Alavés', 'Espanyol',
#        'FC Barcelona', 'Getafe', 'Girona', 'Las Palmas', 'Leganés',
#        'Mallorca', 'Osasuna', 'Rayo Vallecano', 'Real Betis',
#        'Real Madrid', 'Real Sociedad', 'Real Valladolid', 'Sevilla',
#        'Valencia', 'Villarreal', 'Angers SCO', 'Auxerre', 'LOSC Lille',
#        'Le Havre', 'Lens', 'Monaco', 'Montpellier', 'Nantes', 'Nice',
#        'Olympique Lyonnais', 'Olympique de Marseille',
#        'Paris Saint Germain', 'Rennes', 'Saint-Étienne',
# ...

# %%
teams_rating_df.head()
# Out:
#    Unnamed: 0              league                    team  overall  attack  midfield  defence  \
# 0           0  ENG-Premier League         AFC Bournemouth       76      79        76       76
# 1           1  ENG-Premier League                 Arsenal       84      82        85       84
# 2           2  ENG-Premier League             Aston Villa       80      85        79       80
# 3           3  ENG-Premier League               Brentford       76      77        74       76
# 4           4  ENG-Premier League  Brighton & Hove Albion       77      76        76       77
#
#   club_worth  defence_domestic_prestige  international_prestige  players  starting_xi_average_age  \
# 0      €410M                          2                       2       25                    24.82
# 1      €1.9B                          9                       9       24                    25.55
# 2      €800M                          7                       6       25                    26.64
# ...

# %%
extracted_df.head()
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
#
#                         date          home_team                away_team  home_score  away_score  \
# 0  2024-08-16 19:00:00+00:00  Manchester United                   Fulham         1.0         0.0
# 1  2024-08-17 14:00:00+00:00            Arsenal  Wolverhampton Wanderers         2.0         0.0
# 2  2024-08-17 14:00:00+00:00            Everton   Brighton & Hove Albion         0.0         3.0
# ...

# %%
extracted_df["home_team"].unique()
# Out:
# array(['Manchester United', 'Arsenal', 'Everton', 'Ipswich Town',
#        'Newcastle United', 'Nottingham Forest', 'West Ham United',
#        'Brentford', 'Chelsea', 'Leicester City', 'Aston Villa',
#        'Brighton & Hove Albion', 'Crystal Palace', 'Fulham',
#        'Manchester City', 'Southampton', 'Tottenham Hotspur',
#        'AFC Bournemouth', 'Liverpool', 'Wolverhampton Wanderers',
#        'Athletic Club', 'Real Betis', 'Celta Vigo', 'Las Palmas',
#        'Osasuna', 'Valencia', 'Mallorca', 'Real Sociedad',
#        'Real Valladolid', 'Villarreal', 'Sevilla', 'Barcelona',
#        'Espanyol', 'Getafe', 'Atletico Madrid', 'Deportivo Alaves',
#        'Leganes', 'Real Madrid', 'Rayo Vallecano', 'Girona', 'Le Havre',
#        'Brest', 'Monaco', 'Reims', 'Angers', 'Auxerre', 'Montpellier',
#        'Rennes', 'Toulouse', 'Lille', 'Lyon', 'Lens', 'Marseille',
#        'Nantes', 'Nice', 'Strasbourg', 'Borussia Mönchengladbach',
# ...

# %%
i = 10000000

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Define a function to get the best match using TF-IDF and cosine similarity
def tfidf_match(team_name, choices):
    # Combine the team name with the choices
    all_teams = [team_name] + choices.tolist()
    
    # Convert team names into TF-IDF vectors
    vectorizer = TfidfVectorizer().fit(all_teams)
    vectors = vectorizer.transform(all_teams)
    
    # Compute cosine similarity between the first vector (team_name) and the rest
    cosine_similarities = cosine_similarity(vectors[0:1], vectors[1:]).flatten()
    
    # Get the index of the best match
    best_match_idx = np.argmax(cosine_similarities)
    
    # Return the best matching team name from choices
    return choices.iloc[best_match_idx]

# Apply the TF-IDF matching function to both the home_team and away_team columns
extracted_df['home_team_matched'] = extracted_df['home_team'].apply(lambda x: tfidf_match(x, teams_rating_df['team']))
extracted_df['away_team_matched'] = extracted_df['away_team'].apply(lambda x: tfidf_match(x, teams_rating_df['team']))

# Merge the teams_rating data for the home_team with suffix '_home'
merged_df = pd.merge(extracted_df, teams_rating_df, left_on='home_team_matched', right_on='team', suffixes=('', '_home'))
# Rename columns to clearly show they are for the home team
merged_df = merged_df.rename(columns={
    'overall': 'home_overall', 'attack': 'home_attack', 'midfield': 'home_midfield', 
    'defence': 'home_defence', 'club_worth': 'home_club_worth', 
    'defence_domestic_prestige': 'home_defence_domestic_prestige', 
    'international_prestige': 'home_international_prestige'
})

# Merge the teams_rating data for the away_team with suffix '_away'
merged_df = pd.merge(merged_df, teams_rating_df, left_on='away_team_matched', right_on='team', suffixes=('', '_away'))
# Rename columns to clearly show they are for the away team
merged_df = merged_df.rename(columns={
    'overall': 'away_overall', 'attack': 'away_attack', 'midfield': 'away_midfield', 
    'defence': 'away_defence', 'club_worth': 'away_club_worth', 
    'defence_domestic_prestige': 'away_defence_domestic_prestige', 
    'international_prestige': 'away_international_prestige'
})

# Now, you can drop the extra 'team' columns used for merging
merged_df = merged_df.drop(columns=['team', 'team_home', 'team_away'], errors='ignore')

# Ensure that the tactical columns from extracted_df are still included in merged_df
tactical_columns = [
    'home_possession_play', 'away_possession_play', 'home_counter_attack', 'away_counter_attack',
    'home_high_press', 'away_high_press', 'home_direct_play', 'away_direct_play', 
    'home_wing_play', 'away_wing_play', 'home_set_piece_focus', 'away_set_piece_focus', 
    'home_creative_playmaking', 'away_creative_playmaking', 'home_playing_out_back', 'away_playing_out_back',
    'home_low_block', 'away_low_block', 'home_high_defensive_line', 'away_high_defensive_line'
]

# Select only the necessary columns to keep in the final dataframe
final_columns = [
    'home_team', 'home_team_matched', 'away_team', 'away_team_matched',  # Include original and matched team names
    'home_overall', 'away_overall', 'home_attack', 'away_attack',
    'home_midfield', 'away_midfield', 'home_defence', 'away_defence', 'home_club_worth', 'away_club_worth',
    'home_defence_domestic_prestige', 'away_defence_domestic_prestige', 'home_international_prestige',
    'away_international_prestige', 'home_success_score', 'away_success_score'
] + tactical_columns

final_df = merged_df[final_columns]

# Display the final result
print(final_df)
# Out:
#              home_team  home_team_matched                away_team        away_team_matched  \
# 0    Manchester United  Manchester United                   Fulham                   Fulham
# 1              Arsenal            Arsenal  Wolverhampton Wanderers  Wolverhampton Wanderers
# 2              Everton            Everton   Brighton & Hove Albion   Brighton & Hove Albion
# 3         Ipswich Town       Ipswich Town                Liverpool                Liverpool
# 4     Newcastle United   Newcastle United              Southampton              Southampton
# ..                 ...                ...                      ...                      ...
# 425         Fiorentina         Fiorentina                     Roma                     Roma
# 426              Inter              Inter                 Juventus                 Juventus
# 427              Lazio              Lazio                    Genoa                    Genoa
# ...

# %%
import pandas as pd

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 100)

# %%
final_df.tail(99)
# Out:
#          home_team home_team_matched                 away_team         away_team_matched  \
# 331  Holstein Kiel     Holstein Kiel              Union Berlin           FC Union Berlin
# 332      Wolfsburg     VfL Wolfsburg             Werder Bremen             Werder Bremen
# 333       Mainz 05      FSV Mainz 05  Borussia Mönchengladbach  Borussia Mönchengladbach
# 334       Augsburg       FC Augsburg         Borussia Dortmund         Borussia Dortmund
# 335     RB Leipzig        RB Leipzig                  Freiburg               SC Freiburg
# 336      St. Pauli         St. Pauli                 Wolfsburg             VfL Wolfsburg
# 337  VfB Stuttgart     VfB Stuttgart             Holstein Kiel             Holstein Kiel
# 338  Werder Bremen     Werder Bremen          Bayer Leverkusen       Bayer 04 Leverkusen
# 339         Bochum   VfL Bochum 1848            Bayern München         FC Bayern München
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Sample data for demonstration
# extracted_df = pd.DataFrame({'home_team': [...], 'away_team': [...], 'home_possession_play': [...], 'away_possession_play': [...], ...})
# teams_rating_df = pd.DataFrame({'team': [...], 'overall': [...], 'attack': [...], ...})

# Define a function to get the best match using TF-IDF and cosine similarity
def tfidf_match(team_name, choices):
    # Combine the team name with the choices
    all_teams = [team_name] + choices.tolist()
    
    # Convert team names into TF-IDF vectors
    vectorizer = TfidfVectorizer().fit(all_teams)
    vectors = vectorizer.transform(all_teams)
    
    # Compute cosine similarity between the first vector (team_name) and the rest
    cosine_similarities = cosine_similarity(vectors[0:1], vectors[1:]).flatten()
    
    # Get the index of the best match
    best_match_idx = np.argmax(cosine_similarities)
    
    # Return the best matching team name from choices
    return choices.iloc[best_match_idx]

# Apply the TF-IDF matching function to both the home_team and away_team columns
extracted_df['home_team_matched'] = extracted_df['home_team'].apply(lambda x: tfidf_match(x, teams_rating_df['team']))
extracted_df['away_team_matched'] = extracted_df['away_team'].apply(lambda x: tfidf_match(x, teams_rating_df['team']))

# Merge the teams_rating data for the home_team with suffix '_home'
merged_df = pd.merge(extracted_df, teams_rating_df, left_on='home_team_matched', right_on='team', suffixes=('', '_home'))
# Rename columns to clearly show they are for the home team
merged_df = merged_df.rename(columns={
    'overall': 'home_overall', 'attack': 'home_attack', 'midfield': 'home_midfield', 
    'defence': 'home_defence', 'club_worth': 'home_club_worth', 
    'defence_domestic_prestige': 'home_defence_domestic_prestige', 
    'international_prestige': 'home_international_prestige'
})

# Merge the teams_rating data for the away_team with suffix '_away'
merged_df = pd.merge(merged_df, teams_rating_df, left_on='away_team_matched', right_on='team', suffixes=('', '_away'))
# Rename columns to clearly show they are for the away team
merged_df = merged_df.rename(columns={
    'overall': 'away_overall', 'attack': 'away_attack', 'midfield': 'away_midfield', 
    'defence': 'away_defence', 'club_worth': 'away_club_worth', 
    'defence_domestic_prestige': 'away_defence_domestic_prestige', 
    'international_prestige': 'away_international_prestige'
})

# Now, you can drop the extra 'team' columns used for merging
merged_df = merged_df.drop(columns=['team', 'team_home', 'team_away'], errors='ignore')

# Ensure that the tactical columns from extracted_df are still included in merged_df
tactical_columns = [
    'home_possession_play', 'away_possession_play', 'home_counter_attack', 'away_counter_attack',
    'home_high_press', 'away_high_press', 'home_direct_play', 'away_direct_play', 
    'home_wing_play', 'away_wing_play', 'home_set_piece_focus', 'away_set_piece_focus', 
    'home_creative_playmaking', 'away_creative_playmaking', 'home_playing_out_back', 'away_playing_out_back',
    'home_low_block', 'away_low_block', 'home_high_defensive_line', 'away_high_defensive_line'
]

# Select only the necessary columns to keep in the final dataframe
final_columns = [
    'home_team_matched', 'away_team_matched', 'home_overall', 'away_overall', 'home_attack', 'away_attack',
    'home_midfield', 'away_midfield', 'home_defence', 'away_defence', 'home_club_worth', 'away_club_worth',
    'home_defence_domestic_prestige', 'away_defence_domestic_prestige', 'home_international_prestige',
    'away_international_prestige', 'home_success_score', 'away_success_score'
] + tactical_columns

final_df = merged_df[final_columns]

# Display the final result
print(final_df)
# Out:
#      home_team_matched        away_team_matched  home_overall  away_overall  home_attack  \
# 0    Manchester United                   Fulham            81            76           79
# 1              Arsenal  Wolverhampton Wanderers            84            77           82
# 2              Everton   Brighton & Hove Albion            76            77           77
# 3         Ipswich Town                Liverpool            74            84           71
# 4     Newcastle United              Southampton            81            75           80
# ..                 ...                      ...           ...           ...          ...
# 425         Fiorentina                     Roma            77            80           76
# 426              Inter                 Juventus            83            80           86
# 427              Lazio                    Genoa            78            73           80
# ...

# %%
merged_df.head()
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
#
#                         date          home_team                away_team  home_score  away_score  \
# 0  2024-08-16 19:00:00+00:00  Manchester United                   Fulham         1.0         0.0
# 1  2024-08-17 14:00:00+00:00            Arsenal  Wolverhampton Wanderers         2.0         0.0
# 2  2024-08-17 14:00:00+00:00            Everton   Brighton & Hove Albion         0.0         3.0
# ...

# %%
# Remove the unwanted columns
columns_to_remove = [
    'home_team_matched', 'away_team_matched', 'Unnamed: 0', 'league_home', 'home_club_worth', 
    'players', 'starting_xi_average_age', 'whole_team_average_age', 'fifa_edition', 'update', 
    'Unnamed: 0_away', 'league_away', 'away_club_worth', 'players_away', 
    'starting_xi_average_age_away', 'whole_team_average_age_away', 'fifa_edition_away', 'update_away'
]
final_df = merged_df.drop(columns=columns_to_remove, errors='ignore')
# Rename the column in the DataFrame
final_df = final_df.rename(columns={'away_defence_domestic_prestige': 'away_domestic_prestige', "home_defence_domestic_prestige": "home_domestic_prestige"})

final_df.head()
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
#
#                         date          home_team                away_team  home_score  away_score  \
# 0  2024-08-16 19:00:00+00:00  Manchester United                   Fulham         1.0         0.0
# 1  2024-08-17 14:00:00+00:00            Arsenal  Wolverhampton Wanderers         2.0         0.0
# 2  2024-08-17 14:00:00+00:00            Everton   Brighton & Hove Albion         0.0         3.0
# ...

# %%
final_df_merged = final_df

# %%
final_df_merged["league"].unique()
# Out:
# array(['ENG-Premier League', 'ESP-La Liga', 'FRA-Ligue 1',
#        'GER-Bundesliga', 'ITA-Serie A'], dtype=object)

# %%
final_df_merged.head(2)
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
#
#                         date          home_team                away_team  home_score  away_score  \
# 0  2024-08-16 19:00:00+00:00  Manchester United                   Fulham         1.0         0.0
# 1  2024-08-17 14:00:00+00:00            Arsenal  Wolverhampton Wanderers         2.0         0.0
#
#   status  home_possession_play  away_possession_play  home_counter_attack  away_counter_attack  \
# 0     FT               227.032               181.796            59.928571            42.440000
# 1     FT               203.964               178.044            49.088889            45.488889
#
#    home_high_press  away_high_press  home_direct_play  away_direct_play  home_wing_play  \
# ...

# %%
final_df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   league                       430 non-null    object
#  1   season                       430 non-null    int64
#  2   game                         430 non-null    object
#  3   round                        430 non-null    int64
#  4   week                         430 non-null    int64
#  5   date                         430 non-null    object
#  6   home_team                    430 non-null    object
#  7   away_team                    430 non-null    object
#  8   home_score                   430 non-null    float64
#  9   away_score                   430 non-null    float64
#  10  status                       430 non-null    object
#  11  home_possession_play         430 non-null    float64
#  12  away_possession_play         430 non-null    float64
# ...

# %%
t = final_df_merged

# %%
final_df_merged = t

# %%
# Define the desired order of columns
desired_columns = [
    'league', 'season', 'game', 'round', 'week', 'date', 'home_team', 'away_team', 
    "home_score",	"away_score",
    'home_score', 'away_score', 'status', 'home_overall', 'home_attack', 
    'home_midfield', 'home_defence', 'home_domestic_prestige', 'home_international_prestige', 
    'away_overall', 'away_attack', 'away_midfield', 'away_defence', 'away_domestic_prestige', 
    'away_international_prestige', 'home_possession_play', 'home_counter_attack', 
    'home_high_press', 'home_direct_play', 'home_wing_play', 'home_set_piece_focus', 
    'home_creative_playmaking', 'home_playing_out_back', 'home_low_block', 
    'home_high_defensive_line', 'away_possession_play', 'away_counter_attack', 
    'away_high_press', 'away_direct_play', 'away_wing_play', 'away_set_piece_focus', 
    'away_creative_playmaking', 'away_playing_out_back', 'away_low_block', 
    'away_high_defensive_line', 'home_success_score', 'away_success_score'
]

# Reorder the columns in the dataframe
final_df_merged = final_df_merged[desired_columns]

# %%
final_df_merged.dropna(subset=['home_score'])
# Out:
#                  league  season                                        game  round  week  \
# 0    ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1    ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2    ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3    ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4    ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
# ..                  ...     ...                                         ...    ...   ...
# 425         ITA-Serie A    2425                  2024-10-27 Fiorentina-Roma      9     9
# 426         ITA-Serie A    2425                   2024-10-27 Inter-Juventus      9     9
# 427         ITA-Serie A    2425                      2024-10-27 Lazio-Genoa      9     9
# ...

# %%
final_df_merged.dropna(inplace=True)
final_df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 47 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   league                       430 non-null    object
#  1   season                       430 non-null    int64
#  2   game                         430 non-null    object
#  3   round                        430 non-null    int64
#  4   week                         430 non-null    int64
#  5   date                         430 non-null    object
#  6   home_team                    430 non-null    object
#  7   away_team                    430 non-null    object
#  8   home_score                   430 non-null    float64
#  9   away_score                   430 non-null    float64
#  10  home_score                   430 non-null    float64
#  11  away_score                   430 non-null    float64
#  12  status                       430 non-null    object
# ...

# %%
# Print the columns of the dataframe
print(final_df_merged.columns)
# Out:
# Index(['league', 'season', 'game', 'round', 'week', 'date', 'home_team', 'away_team', 'home_score',
#        'away_score', 'home_score', 'away_score', 'status', 'home_overall', 'home_attack',
#        'home_midfield', 'home_defence', 'home_domestic_prestige', 'home_international_prestige',
#        'away_overall', 'away_attack', 'away_midfield', 'away_defence', 'away_domestic_prestige',
#        'away_international_prestige', 'home_possession_play', 'home_counter_attack',
#        'home_high_press', 'home_direct_play', 'home_wing_play', 'home_set_piece_focus',
#        'home_creative_playmaking', 'home_playing_out_back', 'home_low_block',
#        'home_high_defensive_line', 'away_possession_play', 'away_counter_attack',
#        'away_high_press', 'away_direct_play', 'away_wing_play', 'away_set_piece_focus',
#        'away_creative_playmaking', 'away_playing_out_back', 'away_low_block',
#        'away_high_defensive_line', 'home_success_score', 'away_success_score'],
# ...

# %%
df = final_df_merged

# %%
# Reorder the columns to match the desired order
df = df[['league', 'season', "game","round", 'week', 'home_team', 'away_team', 'home_score', 'away_score',
         'home_overall', 'home_attack', 'home_midfield', 'home_defence', 'home_international_prestige',
         'home_domestic_prestige', 'home_possession_play', 'home_counter_attack', 'home_high_press', 
         'home_direct_play', 'home_wing_play', 'home_set_piece_focus', 'home_creative_playmaking',
         'home_playing_out_back', 'home_low_block', 'home_high_defensive_line', 'away_overall',
         'away_attack', 'away_midfield', 'away_defence', 'away_international_prestige', 'away_domestic_prestige',
         'away_possession_play', 'away_counter_attack', 'away_high_press', 'away_direct_play', 'away_wing_play',
         'away_set_piece_focus', 'away_creative_playmaking', 'away_playing_out_back', 'away_low_block',
         'away_high_defensive_line', 'home_success_score', 'away_success_score']]

# %%
# Method to remove duplicate columns
df = df.loc[:, ~df.columns.duplicated()]

# %%
df.tail()
# Out:
#           league  season                        game  round  week   home_team away_team  \
# 425  ITA-Serie A    2425  2024-10-27 Fiorentina-Roma      9     9  Fiorentina      Roma
# 426  ITA-Serie A    2425   2024-10-27 Inter-Juventus      9     9       Inter  Juventus
# 427  ITA-Serie A    2425      2024-10-27 Lazio-Genoa      9     9       Lazio     Genoa
# 428  ITA-Serie A    2425    2024-10-27 Monza-Venezia      9     9       Monza   Venezia
# 429  ITA-Serie A    2425     2024-10-27 Parma-Empoli      9     9       Parma    Empoli
#
#      home_score  away_score  home_overall  home_attack  home_midfield  home_defence  \
# 425         5.0         1.0            77           76             77            76
# 426         4.0         4.0            83           86             83            83
# 427         3.0         0.0            78           80             79            78
# 428         2.0         2.0            74           73             74            74
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   league                       430 non-null    object
#  1   season                       430 non-null    int64
#  2   game                         430 non-null    object
#  3   round                        430 non-null    int64
#  4   week                         430 non-null    int64
#  5   home_team                    430 non-null    object
#  6   away_team                    430 non-null    object
#  7   home_score                   430 non-null    float64
#  8   away_score                   430 non-null    float64
#  9   home_overall                 430 non-null    int64
#  10  home_attack                  430 non-null    int64
#  11  home_midfield                430 non-null    int64
#  12  home_defence                 430 non-null    int64
# ...

# %%
# Assuming you have the DataFrame named 'df'

# Creating the outcome column based on home_score and away_score
def match_outcome(row):
    if row['home_score'] > row['away_score']:
        return 'win'
    elif row['home_score'] < row['away_score']:
        return 'lose'
    else:
        return 'draw'

df['outcome'] = df.apply(match_outcome, axis=1)

# Display the updated DataFrame with the new column
df[['home_score', 'away_score', 'outcome']]
# Out:
#      home_score  away_score outcome
# 0           1.0         0.0     win
# 1           2.0         0.0     win
# 2           0.0         3.0    lose
# 3           0.0         2.0    lose
# 4           1.0         0.0     win
# ..          ...         ...     ...
# 425         5.0         1.0     win
# 426         4.0         4.0    draw
# 427         3.0         0.0     win
# 428         2.0         2.0    draw
# 429         1.0         1.0    draw
#
# [430 rows x 3 columns]

# %%
df.head()
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
#
#            home_team                away_team  home_score  away_score  home_overall  home_attack  \
# 0  Manchester United                   Fulham         1.0         0.0            81           79
# 1            Arsenal  Wolverhampton Wanderers         2.0         0.0            84           82
# 2            Everton   Brighton & Hove Albion         0.0         3.0            76           77
# ...

# %%
import pandas as pd

# Assuming you have your DataFrame named 'df'
# Define conditions
draw_condition = (df['home_success_score'] >= 3.8) & (df['home_success_score'] <= 5.2)
win_condition = df['home_success_score'] > 5.2
lose_condition = df['home_success_score'] < 3.8

# Count the number of correct outcomes based on conditions
draw_count = len(df[draw_condition & (df['outcome'] == 'draw')])
win_count = len(df[win_condition & (df['outcome'] == 'win')])
lose_count = len(df[lose_condition & (df['outcome'] == 'lose')])

# Calculate the total number of rows
total_rows = len(df)

x = draw_count + win_count + lose_count

print(x/total_rows * 100)
# Out:
# 66.74418604651163

# %%
data = df

# %%
data.head()
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
#
#            home_team                away_team  home_score  away_score  home_overall  home_attack  \
# 0  Manchester United                   Fulham         1.0         0.0            81           79
# 1            Arsenal  Wolverhampton Wanderers         2.0         0.0            84           82
# 2            Everton   Brighton & Hove Albion         0.0         3.0            76           77
# ...

# %%
# Iterate over each row in df
for index, row in df.iterrows():
    if row['outcome'] == 'win':
        df.loc[index, 'home_points'] = 3
        df.loc[index, 'away_points'] = 0
    elif row['outcome'] == 'draw':
        df.loc[index, 'home_points'] = 1
        df.loc[index, 'away_points'] = 1
    else:
        df.loc[index, 'home_points'] = 0
        df.loc[index, 'away_points'] = 3
df.head()
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
#
#            home_team                away_team  home_score  away_score  home_overall  home_attack  \
# 0  Manchester United                   Fulham         1.0         0.0            81           79
# 1            Arsenal  Wolverhampton Wanderers         2.0         0.0            84           82
# 2            Everton   Brighton & Hove Albion         0.0         3.0            76           77
# ...

# %%
df.head()
# Out:
#                league  season                                        game  round  week  \
# 0  ENG-Premier League    2425         2024-08-16 Manchester United-Fulham      1     1
# 1  ENG-Premier League    2425  2024-08-17 Arsenal-Wolverhampton Wanderers      1     1
# 2  ENG-Premier League    2425   2024-08-17 Everton-Brighton & Hove Albion      1     1
# 3  ENG-Premier League    2425           2024-08-17 Ipswich Town-Liverpool      1     1
# 4  ENG-Premier League    2425     2024-08-17 Newcastle United-Southampton      1     1
#
#            home_team                away_team  home_score  away_score  home_overall  home_attack  \
# 0  Manchester United                   Fulham         1.0         0.0            81           79
# 1            Arsenal  Wolverhampton Wanderers         2.0         0.0            84           82
# 2            Everton   Brighton & Hove Albion         0.0         3.0            76           77
# ...

# %%
import pandas as pd

# Assuming you already have the dataset loaded in a DataFrame called 'df'

# Create home dataset with only columns relevant to the home team
home_columns = ['league', 'season', 'week', 'home_team', 'home_score', 'away_score', 'home_overall', 'home_attack', 
                'home_midfield', 'home_defence', 'home_international_prestige', 'home_domestic_prestige', 
                'home_possession_play', 'home_counter_attack', 'home_high_press', 'home_direct_play', 
                'home_wing_play', 'home_set_piece_focus', 'home_creative_playmaking', 'home_playing_out_back', 
                'home_low_block', 'home_high_defensive_line', 'home_success_score', 'outcome', "home_points"]

home_dataset = df[home_columns].copy()

# Rename the columns in home dataset by removing 'home_' prefix
home_dataset.columns = [col.replace('home_', '') if 'home_' in col else col for col in home_dataset.columns]
# Rename 'away_score' to 'conceded_goals' for the home dataset
home_dataset = home_dataset.rename(columns={'away_score': 'conceded_goals'})

# Create away dataset with only columns relevant to the away team
away_columns = ['league', 'season', 'week', 'away_team', 'away_score', 'home_score', 'away_overall', 'away_attack', 
                'away_midfield', 'away_defence', 'away_international_prestige', 'away_domestic_prestige', 
                'away_possession_play', 'away_counter_attack', 'away_high_press', 'away_direct_play', 
                'away_wing_play', 'away_set_piece_focus', 'away_creative_playmaking', 'away_playing_out_back', 
                'away_low_block', 'away_high_defensive_line', 'away_success_score', 'outcome', "away_points"]

away_dataset = df[away_columns].copy()

# Rename the columns in away dataset by removing 'away_' prefix
away_dataset.columns = [col.replace('away_', '') if 'away_' in col else col for col in away_dataset.columns]
# Rename 'home_score' to 'conceded_goals' for the away dataset
away_dataset = away_dataset.rename(columns={'home_score': 'conceded_goals'})

# %%
import pandas as pd

# Assuming df, home_dataset, and away_dataset are already loaded

# List of features to calculate rolling averages for
rolling_features = ['possession_play', 'counter_attack', 
                    'high_press', 'direct_play', 'wing_play', 'set_piece_focus', 
                    'creative_playmaking', 'playing_out_back', 'low_block', 'high_defensive_line', 'success_score', 'conceded_goals','score','points']
                    
# Initialize empty lists to store rolling average columns
for feature in rolling_features:
    df[f'home_{feature}_rolling_avg'] = None
    df[f'away_{feature}_rolling_avg'] = None

# Function to calculate rolling averages for a given team in a dataset
def calculate_rolling_average(team, week, league, season, home_dataset, away_dataset):
    # Filter the dataset for the same team, league, and season
    team_data1 = home_dataset[(home_dataset['team'] == team) & (home_dataset['league'] == league) & (home_dataset['season'] == season)]
    team_data2 = away_dataset[(away_dataset['team'] == team) & (away_dataset['league'] == league) & (away_dataset['season'] == season)]

    # Concatenate the two datasets
    team_data = pd.concat([team_data1, team_data2])

# Convert the 'week' column to numeric (forcing errors to NaN, if any)
    team_data['week'] = pd.to_numeric(team_data['week'], errors='coerce')
    previous_weeks = team_data[team_data['week'] < int(week)].sort_values(by='week', ascending=False).head(i)
    
    # Calculate the mean for the rolling features
    rolling_avg = {}
    for feature in rolling_features:
        if not previous_weeks.empty:
            rolling_avg[feature] = np.round(previous_weeks[feature].mean(), 2)

        else:
            rolling_avg[feature] = None  # No previous data available
            
    return rolling_avg

# Iterate over each row in df
for index, row in df.iterrows():
    league = row['league']
    season = row['season']
    week = row['week']
    home_team = row['home_team']
    away_team = row['away_team']
    
    # Calculate rolling averages for the home team
    home_rolling_avg = calculate_rolling_average(home_team, week, league, season, home_dataset, away_dataset)
    
    # Calculate rolling averages for the away team
    away_rolling_avg = calculate_rolling_average(away_team, week, league, season, home_dataset, away_dataset)
    
    # Update the original dataframe with the calculated rolling averages
    for feature in rolling_features:
        df.at[index, f'home_{feature}_rolling_avg'] = home_rolling_avg[feature]
        df.at[index, f'away_{feature}_rolling_avg'] = away_rolling_avg[feature]

# # Check the updated dataframe
# print(df.head())

# %%
import numpy as np

# Initialize columns for rolling_avg2
for feature in rolling_features:
    df[f'home_{feature}_rolling_avg2'] = None
    df[f'away_{feature}_rolling_avg2'] = None

# Function to calculate rolling averages for 10,000 previous rows for a given team in a dataset
def calculate_rolling_average_10000(team, week, league, season, home_dataset, away_dataset):
    # Filter the dataset for the same team, league, and season
    team_data1 = home_dataset[(home_dataset['team'] == team) & (home_dataset['league'] == league) & (home_dataset['season'] == season)]
    team_data2 = away_dataset[(away_dataset['team'] == team) & (away_dataset['league'] == league) & (away_dataset['season'] == season)]

    # Concatenate the two datasets
    team_data = pd.concat([team_data1, team_data2])

    # Convert the 'week' column to numeric (forcing errors to NaN, if any)
    team_data['week'] = pd.to_numeric(team_data['week'], errors='coerce')

    previous_weeks = team_data[team_data['week'] < int(week)].sort_values(by='week', ascending=False).head(10)
    
    # Calculate the mean for the rolling features
    rolling_avg2 = {}
    for feature in rolling_features:
        if not previous_weeks.empty:
            rolling_avg2[feature] = np.round(previous_weeks[feature].mean(), 2)
        else:
            rolling_avg2[feature] = None  # No previous data available
            
    return rolling_avg2

# Iterate over each row in df for rolling_avg2 calculation
for index, row in df.iterrows():
    league = row['league']
    season = row['season']
    week = row['week']
    home_team = row['home_team']
    away_team = row['away_team']
    
    # Calculate rolling_avg2 for the home team
    home_rolling_avg2 = calculate_rolling_average_10000(home_team, week, league, season, home_dataset, away_dataset)
    
    # Calculate rolling_avg2 for the away team
    away_rolling_avg2 = calculate_rolling_average_10000(away_team, week, league, season, home_dataset, away_dataset)
    
    # Update the original dataframe with the calculated rolling_avg2
    for feature in rolling_features:
        df.at[index, f'home_{feature}_rolling_avg2'] = home_rolling_avg2[feature]
        df.at[index, f'away_{feature}_rolling_avg2'] = away_rolling_avg2[feature]

# # Check the updated dataframe
# print(df.head())

# %%
columns_to_drop = ['home_possession_play', 'home_counter_attack', 'home_high_press','home_direct_play', 'home_wing_play', 'home_set_piece_focus', 'home_creative_playmaking', 'home_playing_out_back', 'home_low_block', 'home_high_defensive_line', 'away_possession_play', 'away_counter_attack', 'away_high_press', 'away_direct_play', 'away_wing_play', 'away_set_piece_focus', 'away_creative_playmaking', 'away_playing_out_back', 'away_low_block', 'away_high_defensive_line']
df.drop(columns=columns_to_drop, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382 entries, 10 to 429
# Data columns (total 82 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   league                                 382 non-null    object
#  1   season                                 382 non-null    int64
#  2   game                                   382 non-null    object
#  3   round                                  382 non-null    int64
#  4   week                                   382 non-null    int64
#  5   home_team                              382 non-null    object
#  6   away_team                              382 non-null    object
#  7   home_score                             382 non-null    float64
#  8   away_score                             382 non-null    float64
#  9   home_overall                           382 non-null    int64
#  10  home_attack                            382 non-null    int64
# ...

# %%
df.head()
# Out:
#                 league  season                                               game  round  week  \
# 10  ENG-Premier League    2425                     2024-08-24 Aston Villa-Arsenal      2     2
# 11  ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 12  ENG-Premier League    2425          2024-08-24 Crystal Palace-West Ham United      2     2
# 13  ENG-Premier League    2425                   2024-08-24 Fulham-Leicester City      2     2
# 14  ENG-Premier League    2425            2024-08-24 Manchester City-Ipswich Town      2     2
#
#                  home_team          away_team  home_score  away_score  home_overall  home_attack  \
# 10             Aston Villa            Arsenal         0.0         2.0            80           85
# 11  Brighton & Hove Albion  Manchester United         2.0         1.0            77           76
# 12          Crystal Palace    West Ham United         0.0         2.0            78           78
# ...

# %%
data = df

# %%
data.tail()
# Out:
#           league  season                        game  round  week   home_team away_team  \
# 425  ITA-Serie A    2425  2024-10-27 Fiorentina-Roma      9     9  Fiorentina      Roma
# 426  ITA-Serie A    2425   2024-10-27 Inter-Juventus      9     9       Inter  Juventus
# 427  ITA-Serie A    2425      2024-10-27 Lazio-Genoa      9     9       Lazio     Genoa
# 428  ITA-Serie A    2425    2024-10-27 Monza-Venezia      9     9       Monza   Venezia
# 429  ITA-Serie A    2425     2024-10-27 Parma-Empoli      9     9       Parma    Empoli
#
#      home_score  away_score  home_overall  home_attack  home_midfield  home_defence  \
# 425         5.0         1.0            77           76             77            76
# 426         4.0         4.0            83           86             83            83
# 427         3.0         0.0            78           80             79            78
# 428         2.0         2.0            74           73             74            74
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382 entries, 10 to 429
# Data columns (total 82 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   league                                 382 non-null    object
#  1   season                                 382 non-null    int64
#  2   game                                   382 non-null    object
#  3   round                                  382 non-null    int64
#  4   week                                   382 non-null    int64
#  5   home_team                              382 non-null    object
#  6   away_team                              382 non-null    object
#  7   home_score                             382 non-null    float64
#  8   away_score                             382 non-null    float64
#  9   home_overall                           382 non-null    int64
#  10  home_attack                            382 non-null    int64
# ...

# %%
import pandas as pd

# Assuming you have a DataFrame called 'df' with a 'league' column

# One-Hot Encoding
one_hot_encoded = pd.get_dummies(df['league'], prefix='league')

# Label Encoding
label_encoded = df['league'].astype('category').cat.codes

# Adding the encoded columns to the DataFrame
df_encoded = pd.concat([df, one_hot_encoded], axis=1)
df['league_label_encoded'] = label_encoded

df.tail()
# Out:
#           league  season                        game  round  week   home_team away_team  \
# 425  ITA-Serie A    2425  2024-10-27 Fiorentina-Roma      9     9  Fiorentina      Roma
# 426  ITA-Serie A    2425   2024-10-27 Inter-Juventus      9     9       Inter  Juventus
# 427  ITA-Serie A    2425      2024-10-27 Lazio-Genoa      9     9       Lazio     Genoa
# 428  ITA-Serie A    2425    2024-10-27 Monza-Venezia      9     9       Monza   Venezia
# 429  ITA-Serie A    2425     2024-10-27 Parma-Empoli      9     9       Parma    Empoli
#
#      home_score  away_score  home_overall  home_attack  home_midfield  home_defence  \
# 425         5.0         1.0            77           76             77            76
# 426         4.0         4.0            83           86             83            83
# 427         3.0         0.0            78           80             79            78
# 428         2.0         2.0            74           73             74            74
# ...

# %%
df['week'] = pd.to_numeric(df['week'], errors='coerce')

# %%
# df = df[df['week'] <= 10]
# df = df[df["league"] != 'FRA-Ligue 1']

# %%
final_df_merged = df

# %%
df.head()
# Out:
#                 league  season                                               game  round  week  \
# 10  ENG-Premier League    2425                     2024-08-24 Aston Villa-Arsenal      2     2
# 11  ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 12  ENG-Premier League    2425          2024-08-24 Crystal Palace-West Ham United      2     2
# 13  ENG-Premier League    2425                   2024-08-24 Fulham-Leicester City      2     2
# 14  ENG-Premier League    2425            2024-08-24 Manchester City-Ipswich Town      2     2
#
#                  home_team          away_team  home_score  away_score  home_overall  home_attack  \
# 10             Aston Villa            Arsenal         0.0         2.0            80           85
# 11  Brighton & Hove Albion  Manchester United         2.0         1.0            77           76
# 12          Crystal Palace    West Ham United         0.0         2.0            78           78
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382 entries, 10 to 429
# Data columns (total 83 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   league                                 382 non-null    object
#  1   season                                 382 non-null    int64
#  2   game                                   382 non-null    object
#  3   round                                  382 non-null    int64
#  4   week                                   382 non-null    int64
#  5   home_team                              382 non-null    object
#  6   away_team                              382 non-null    object
#  7   home_score                             382 non-null    float64
#  8   away_score                             382 non-null    float64
#  9   home_overall                           382 non-null    int64
#  10  home_attack                            382 non-null    int64
# ...

# %%
final_df_merged["p_home_success_score"] = final_df_merged["home_success_score"]
final_df_merged["p_away_success_score"] = final_df_merged["away_success_score"]

# %%
final_df_merged.head()
# Out:
#                 league  season                                               game  round  week  \
# 10  ENG-Premier League    2425                     2024-08-24 Aston Villa-Arsenal      2     2
# 11  ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 12  ENG-Premier League    2425          2024-08-24 Crystal Palace-West Ham United      2     2
# 13  ENG-Premier League    2425                   2024-08-24 Fulham-Leicester City      2     2
# 14  ENG-Premier League    2425            2024-08-24 Manchester City-Ipswich Town      2     2
#
#                  home_team          away_team  home_score  away_score  home_overall  home_attack  \
# 10             Aston Villa            Arsenal         0.0         2.0            80           85
# 11  Brighton & Hove Albion  Manchester United         2.0         1.0            77           76
# 12          Crystal Palace    West Ham United         0.0         2.0            78           78
# ...

# %%
final_df_merged.to_csv('test.csv')

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import joblib

# Model Definition with Tanh activation
class DeepNeuralNetwork(nn.Module):
    def __init__(self):
        super(DeepNeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(68, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 64)
        self.fc4 = nn.Linear(64, 1)
        self.tanh = nn.Tanh()
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, x):
        x = self.tanh(self.fc1(x))
        x = self.dropout(x)
        x = self.tanh(self.fc2(x))
        x = self.dropout(x)
        x = self.tanh(self.fc3(x))
        x = self.fc4(x)  # No activation for the final layer
        return x

# Load the trained model
model = DeepNeuralNetwork()
model.load_state_dict(torch.load('/Users/farzammanafzadeh/Desktop/Tactics/First Phase/best_model_tanh.pth'))
model.eval()

# Load the scaler
scaler = joblib.load('/Users/farzammanafzadeh/Desktop/Tactics/First Phase/scaler.pkl')




# Assuming 'data' is a DataFrame that contains all the feature columns
feature_columns = [
    'home_overall', 'home_attack', 'home_midfield', 'home_defence', 'home_international_prestige',
    'home_domestic_prestige', 'home_possession_play_rolling_avg', 'home_counter_attack_rolling_avg',
    'home_high_press_rolling_avg', 'home_direct_play_rolling_avg', 'home_wing_play_rolling_avg',
    'home_set_piece_focus_rolling_avg', 'home_creative_playmaking_rolling_avg', 'home_playing_out_back_rolling_avg',
    'home_low_block_rolling_avg', 'home_high_defensive_line_rolling_avg', 'home_success_score_rolling_avg',
    'home_conceded_goals_rolling_avg', 'home_score_rolling_avg', 'home_points_rolling_avg',
    'home_possession_play_rolling_avg2', 'home_counter_attack_rolling_avg2',
    'home_high_press_rolling_avg2', 'home_direct_play_rolling_avg2', 'home_wing_play_rolling_avg2',
    'home_set_piece_focus_rolling_avg2', 'home_creative_playmaking_rolling_avg2', 'home_playing_out_back_rolling_avg2',
    'home_low_block_rolling_avg2', 'home_high_defensive_line_rolling_avg2', 'home_success_score_rolling_avg2',
    'home_conceded_goals_rolling_avg2', 'home_score_rolling_avg2', 'home_points_rolling_avg2',

    'away_overall', 'away_attack', 'away_midfield', 'away_defence', 'away_international_prestige',
    'away_domestic_prestige', 'away_possession_play_rolling_avg', 'away_counter_attack_rolling_avg',
    'away_high_press_rolling_avg', 'away_direct_play_rolling_avg', 'away_wing_play_rolling_avg',
    'away_set_piece_focus_rolling_avg', 'away_creative_playmaking_rolling_avg', 'away_playing_out_back_rolling_avg',
    'away_low_block_rolling_avg', 'away_high_defensive_line_rolling_avg', 'away_success_score_rolling_avg',
    'away_conceded_goals_rolling_avg', 'away_score_rolling_avg', 'away_points_rolling_avg',
    'away_possession_play_rolling_avg2', 'away_counter_attack_rolling_avg2',
    'away_high_press_rolling_avg2', 'away_direct_play_rolling_avg2', 'away_wing_play_rolling_avg2',
    'away_set_piece_focus_rolling_avg2', 'away_creative_playmaking_rolling_avg2', 'away_playing_out_back_rolling_avg2',
    'away_low_block_rolling_avg2', 'away_high_defensive_line_rolling_avg2', 'away_success_score_rolling_avg2',
    'away_conceded_goals_rolling_avg2', 'away_score_rolling_avg2', 'away_points_rolling_avg2'
]

# Prepare the new DataFrame to store results
predicted_results = final_df_merged[['league', 'season', 'game', 'round', 'week', 
                                     'home_team', 'away_team', 'home_score', 'away_score',"p_home_success_score", "p_away_success_score"]].copy()

# Placeholder list for predictions
home_success_scores = []

# Iterating over each row in the final_df_merged to make predictions
for _, row in final_df_merged.iterrows():
    # Extracting the features for the model prediction
    features = row[feature_columns].values.reshape(1, -1)
    
    # Normalizing the features
    features_scaled = scaler.transform(features)
    
    # Converting the features to a PyTorch tensor
    features_tensor = torch.tensor(features_scaled, dtype=torch.float32)
    
    # Predicting the home success score
    with torch.no_grad():
        home_success_score = model(features_tensor).item()
        home_success_score_rounded = round(home_success_score, 2)
        home_success_scores.append(home_success_score_rounded)

# Add predicted home success scores and calculated away success scores to the DataFrame
predicted_results['home_success_score'] = home_success_scores
predicted_results['away_success_score'] = [round(10 - score, 2) for score in home_success_scores]

# Display the results
print(predicted_results.head())
# Out:
#                 league  season                                               game  round  week  \
# 10  ENG-Premier League    2425                     2024-08-24 Aston Villa-Arsenal      2     2
# 11  ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 12  ENG-Premier League    2425          2024-08-24 Crystal Palace-West Ham United      2     2
# 13  ENG-Premier League    2425                   2024-08-24 Fulham-Leicester City      2     2
# 14  ENG-Premier League    2425            2024-08-24 Manchester City-Ipswich Town      2     2
#
#                  home_team          away_team  home_score  away_score  p_home_success_score  \
# 10             Aston Villa            Arsenal         0.0         2.0                  3.78
# 11  Brighton & Hove Albion  Manchester United         2.0         1.0                  5.67
# 12          Crystal Palace    West Ham United         0.0         2.0                  3.65
# ...

# %%
predicted_results.dropna(inplace=True)

# %%
predicted_results.tail(5)
# Out:
#           league  season                        game  round  week   home_team away_team  \
# 425  ITA-Serie A    2425  2024-10-27 Fiorentina-Roma      9     9  Fiorentina      Roma
# 426  ITA-Serie A    2425   2024-10-27 Inter-Juventus      9     9       Inter  Juventus
# 427  ITA-Serie A    2425      2024-10-27 Lazio-Genoa      9     9       Lazio     Genoa
# 428  ITA-Serie A    2425    2024-10-27 Monza-Venezia      9     9       Monza   Venezia
# 429  ITA-Serie A    2425     2024-10-27 Parma-Empoli      9     9       Parma    Empoli
#
#      home_score  away_score  p_home_success_score  p_away_success_score  home_success_score  \
# 425         5.0         1.0                  6.53                  3.47                4.79
# 426         4.0         4.0                  5.03                  4.97                4.59
# 427         3.0         0.0                  7.77                  2.23                6.59
# ...

# %%
import pandas as pd
predicted_results_df = predicted_results
def determine_prediction(home_success_score, away_success_score):
    if 4.6 <= home_success_score <= 5.3:
        return 'draw'
    elif home_success_score > 5.3:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score']), axis=1
)

# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate the number of correct predictions
correct_predictions = (predicted_results_df['predicted_outcome'] == predicted_results_df['actual_outcome']).sum()

# Display the number of correct predictions
print(f"Number of correct predictions: {correct_predictions}")
# Out:
# Number of correct predictions: 173

# %%
import numpy as np

# Calculate the Mean Squared Error (MSE)
mse = np.mean((predicted_results['p_home_success_score'] - predicted_results['home_success_score']) ** 2)
print("Mean Squared Error (MSE):", mse)

# Calculate the Mean Absolute Error (MAE)
mae = np.mean(np.abs(predicted_results['p_home_success_score'] - predicted_results['home_success_score']))
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 1.6931568062827227
# Mean Absolute Error (MAE): 1.0607068062827225

# %%
import numpy as np

# Calculate the Mean Absolute Error (MAE) for your model
mae_model = np.mean(np.abs(predicted_results['p_home_success_score'] - predicted_results['home_success_score']))

# Calculate the mean and median of the actual success scores
mean_score = predicted_results['home_success_score'].mean()
print(mean_score)
median_score = predicted_results['home_success_score'].median()
print(median_score)

# Calculate MAE for the mean as a constant prediction
mae_mean = np.mean(np.abs(mean_score - predicted_results['home_success_score']))

# Calculate MAE for the median as a constant prediction
mae_median = np.mean(np.abs(median_score - predicted_results['home_success_score']))

# Output the results
print("Model MAE:", mae_model)
print("Mean Prediction MAE:", mae_mean)
print("Median Prediction MAE:", mae_median)
# Out:
# 5.386387434554973
# 5.325
# Model MAE: 1.0607068062827225
# Mean Prediction MAE: 0.755718319125024
# Median Prediction MAE: 0.7538219895287959

# %%
import numpy as np
import pandas as pd

# Assuming 'predicted_results' is a DataFrame that includes a 'league' column

# Group by league and calculate MSE and MAE for each league
league_metrics = predicted_results.groupby('league').apply(lambda group: pd.Series({
    'MSE': np.mean((group['p_home_success_score'] - group['home_success_score']) ** 2),
    'MAE': np.mean(np.abs(group['p_home_success_score'] - group['home_success_score']))
}))

# Display the results
print("Mean Squared Error (MSE) and Mean Absolute Error (MAE) by League:")
print(league_metrics)
# Out:
# Mean Squared Error (MSE) and Mean Absolute Error (MAE) by League:
#                          MSE       MAE
# league
# ENG-Premier League  1.553791  0.958875
# ESP-La Liga         1.862476  1.107172
# FRA-Ligue 1         1.875683  1.160156
# GER-Bundesliga      1.578144  1.054098
# ITA-Serie A         1.561372  1.029744

# %%
import numpy as np
import pandas as pd

# Assuming 'predicted_results' is a DataFrame that includes a 'week' column

# Group by week and calculate MSE and MAE for each week
week_metrics = predicted_results.groupby('week').apply(lambda group: pd.Series({
    'MSE': np.mean((group['p_home_success_score'] - group['home_success_score']) ** 2),
    'MAE': np.mean(np.abs(group['p_home_success_score'] - group['home_success_score']))
}))

# Display the results
print("Mean Squared Error (MSE) and Mean Absolute Error (MAE) by Week:")
print(week_metrics)
# Out:
# Mean Squared Error (MSE) and Mean Absolute Error (MAE) by Week:
#            MSE       MAE
# week
# 2     1.981404  1.163478
# 3     1.616713  1.110833
# 4     2.131727  1.166889
# 5     1.663750  1.109583
# 6     1.621757  1.029565
# 7     1.009055  0.793617
# 8     1.646285  1.026739
# 9     1.432868  0.976486
# 10    2.203490  1.017000
# 11    3.271656  1.598889

# %%
df = predicted_results

# %%
# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df['difference'] = abs(df['p_home_success_score'] - df['home_success_score'])

# Sort by the difference in descending order
df_sorted_by_difference = df.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_sorted_by_difference).head(20)
# Out:
#                  league  season                                            game  round  week  \
# 183         ESP-La Liga    2425                 2024-10-19 Girona-Real Sociedad     10    10
# 15   ENG-Premier League    2425        2024-08-24 Southampton-Nottingham Forest      2     2
# 70   ENG-Premier League    2425              2024-10-19 AFC Bournemouth-Arsenal      8     8
# 302      GER-Bundesliga    2425               2024-09-21 FC Heidenheim-Freiburg      4     4
# 122         ESP-La Liga    2425                     2024-08-31 Leganes-Mallorca      4     4
# 418         ITA-Serie A    2425                     2024-10-20 Lecce-Fiorentina      8     8
# 197         ESP-La Liga    2425           2024-10-27 Real Betis-Atletico Madrid     11    11
# 131         ESP-La Liga    2425                  2024-09-14 Mallorca-Villarreal      5     5
# 269         FRA-Ligue 1    2425                 2024-10-27 Montpellier-Toulouse      9     9
# ...

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['home_team'] == 'Manchester United'].copy()

# Calculate the difference between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_home_success_score'] - df_manchester_united['home_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#                 league  season                                            game  round  week  \
# 58  ENG-Premier League    2425  2024-09-29 Manchester United-Tottenham Hotspur      6     6
# 28  ENG-Premier League    2425          2024-09-01 Manchester United-Liverpool      3     3
# 73  ENG-Premier League    2425          2024-10-19 Manchester United-Brentford      8     8
#
#             home_team          away_team  home_score  away_score  p_home_success_score  \
# 58  Manchester United  Tottenham Hotspur         0.0         3.0                  2.84
# 28  Manchester United          Liverpool         0.0         3.0                  3.36
# 73  Manchester United          Brentford         2.0         1.0                  5.87
#
#     p_away_success_score  home_success_score  away_success_score predicted_outcome actual_outcome  \
# 58                  7.16                5.38                4.62          home_win       away_win
# ...

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['away_team'] == 'Manchester United'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_away_success_score'] - df_manchester_united['away_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#                 league  season                                               game  round  week  \
# 37  ENG-Premier League    2425           2024-09-14 Southampton-Manchester United      4     4
# 41  ENG-Premier League    2425        2024-09-21 Crystal Palace-Manchester United      5     5
# 89  ENG-Premier League    2425       2024-10-27 West Ham United-Manchester United      9     9
# 11  ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 67  ENG-Premier League    2425           2024-10-06 Aston Villa-Manchester United      7     7
#
#                  home_team          away_team  home_score  away_score  p_home_success_score  \
# 37             Southampton  Manchester United         0.0         3.0                  3.05
# 41          Crystal Palace  Manchester United         0.0         0.0                  4.28
# 89         West Ham United  Manchester United         2.0         1.0                  5.37
# ...

# %% [markdown]
# # Barcelona

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['home_team'] == 'Barcelona'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_home_success_score'] - df_manchester_united['home_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#           league  season                                  game  round  week  home_team  \
# 155  ESP-La Liga    2425           2024-09-25 Barcelona-Getafe      7     7  Barcelona
# 120  ESP-La Liga    2425  2024-08-31 Barcelona-Real Valladolid      4     4  Barcelona
# 102  ESP-La Liga    2425    2024-08-24 Barcelona-Athletic Club      2     2  Barcelona
# 186  ESP-La Liga    2425          2024-10-20 Barcelona-Sevilla     10    10  Barcelona
#
#            away_team  home_score  away_score  p_home_success_score  p_away_success_score  \
# 155           Getafe         1.0         0.0                  6.88                  3.12
# 120  Real Valladolid         7.0         0.0                  7.61                  2.39
# 102    Athletic Club         2.0         1.0                  5.89                  4.11
# 186          Sevilla         5.0         1.0                  6.31                  3.69
#
# ...

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['away_team'] == 'Barcelona'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_away_success_score'] - df_manchester_united['away_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#           league  season                                   game  round  week         home_team  \
# 193  ESP-La Liga    2425       2024-10-26 Real Madrid-Barcelona     11    11       Real Madrid
# 162  ESP-La Liga    2425           2024-09-28 Osasuna-Barcelona      8     8           Osasuna
# 176  ESP-La Liga    2425  2024-10-06 Deportivo Alaves-Barcelona      9     9  Deportivo Alaves
# 136  ESP-La Liga    2425            2024-09-15 Girona-Barcelona      5     5            Girona
# 150  ESP-La Liga    2425        2024-09-22 Villarreal-Barcelona      6     6        Villarreal
#
#      away_team  home_score  away_score  p_home_success_score  p_away_success_score  \
# 193  Barcelona         0.0         4.0                  3.35                  6.65
# 162  Barcelona         4.0         2.0                  5.68                  4.32
# 176  Barcelona         0.0         3.0                  2.67                  7.33
# ...

# %% [markdown]
# # Real Madrid

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['home_team'] == 'Real Madrid'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_home_success_score'] - df_manchester_united['home_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#           league  season                                     game  round  week    home_team  \
# 152  ESP-La Liga    2425  2024-09-24 Real Madrid-Deportivo Alaves      7     7  Real Madrid
# 193  ESP-La Liga    2425         2024-10-26 Real Madrid-Barcelona     11    11  Real Madrid
# 174  ESP-La Liga    2425        2024-10-05 Real Madrid-Villarreal      9     9  Real Madrid
# 109  ESP-La Liga    2425   2024-08-25 Real Madrid-Real Valladolid      2     2  Real Madrid
# 127  ESP-La Liga    2425        2024-09-01 Real Madrid-Real Betis      4     4  Real Madrid
#
#             away_team  home_score  away_score  p_home_success_score  p_away_success_score  \
# 152  Deportivo Alaves         3.0         2.0                  5.47                  4.53
# 193         Barcelona         0.0         4.0                  3.35                  6.65
# 174        Villarreal         2.0         0.0                  6.14                  3.86
# ...

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['away_team'] == 'Real Madrid'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_away_success_score'] - df_manchester_united['away_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#           league  season                                    game  round  week        home_team  \
# 132  ESP-La Liga    2425    2024-09-14 Real Sociedad-Real Madrid      5     5    Real Sociedad
# 166  ESP-La Liga    2425  2024-09-29 Atletico Madrid-Real Madrid      8     8  Atletico Madrid
# 182  ESP-La Liga    2425       2024-10-19 Celta Vigo-Real Madrid     10    10       Celta Vigo
# 118  ESP-La Liga    2425       2024-08-29 Las Palmas-Real Madrid      3     3       Las Palmas
#
#        away_team  home_score  away_score  p_home_success_score  p_away_success_score  \
# 132  Real Madrid         0.0         2.0                  3.13                  6.87
# 166  Real Madrid         1.0         1.0                  5.41                  4.59
# 182  Real Madrid         1.0         2.0                  5.04                  4.96
# 118  Real Madrid         1.0         1.0                  3.86                  6.14
#
# ...

# %% [markdown]
# # Manchester City

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['home_team'] == 'Manchester City'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_home_success_score'] - df_manchester_united['home_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#                 league  season                                     game  round  week  \
# 65  ENG-Premier League    2425        2024-10-05 Manchester City-Fulham      7     7
# 36  ENG-Premier League    2425     2024-09-14 Manchester City-Brentford      4     4
# 49  ENG-Premier League    2425       2024-09-22 Manchester City-Arsenal      5     5
# 85  ENG-Premier League    2425   2024-10-26 Manchester City-Southampton      9     9
# 14  ENG-Premier League    2425  2024-08-24 Manchester City-Ipswich Town      2     2
#
#           home_team     away_team  home_score  away_score  p_home_success_score  \
# 65  Manchester City        Fulham         3.0         2.0                  5.00
# 36  Manchester City     Brentford         2.0         1.0                  6.02
# 49  Manchester City       Arsenal         2.0         2.0                  5.55
# 85  Manchester City   Southampton         1.0         0.0                  7.69
# ...

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['away_team'] == 'Manchester City'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_away_success_score'] - df_manchester_united['away_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#                 league  season                                               game  round  week  \
# 54  ENG-Premier League    2425        2024-09-28 Newcastle United-Manchester City      6     6
# 78  ENG-Premier League    2425  2024-10-20 Wolverhampton Wanderers-Manchester ...      8     8
# 26  ENG-Premier League    2425         2024-08-31 West Ham United-Manchester City      3     3
#
#                   home_team        away_team  home_score  away_score  p_home_success_score  \
# 54         Newcastle United  Manchester City         1.0         1.0                  5.47
# 78  Wolverhampton Wanderers  Manchester City         1.0         2.0                  4.12
# 26          West Ham United  Manchester City         1.0         3.0                  3.59
#
#     p_away_success_score  home_success_score  away_success_score predicted_outcome actual_outcome  \
# 54                  4.53                4.93                5.07              draw           draw
# ...

# %% [markdown]
# # Arsenal

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['home_team'] == 'Arsenal'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_home_success_score'] - df_manchester_united['home_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#                 league  season                                       game  round  week home_team  \
# 20  ENG-Premier League    2425  2024-08-31 Arsenal-Brighton & Hove Albion      3     3   Arsenal
# 86  ENG-Premier League    2425               2024-10-27 Arsenal-Liverpool      9     9   Arsenal
# 50  ENG-Premier League    2425          2024-09-28 Arsenal-Leicester City      6     6   Arsenal
# 60  ENG-Premier League    2425             2024-10-05 Arsenal-Southampton      7     7   Arsenal
#
#                  away_team  home_score  away_score  p_home_success_score  p_away_success_score  \
# 20  Brighton & Hove Albion         1.0         1.0                  5.18                  4.82
# 86               Liverpool         2.0         2.0                  5.06                  4.94
# 50          Leicester City         4.0         2.0                  6.02                  3.98
# 60             Southampton         3.0         1.0                  6.47                  3.53
#
# ...

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['away_team'] == 'Arsenal'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_away_success_score'] - df_manchester_united['away_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#                 league  season                                  game  round  week  \
# 70  ENG-Premier League    2425    2024-10-19 AFC Bournemouth-Arsenal      8     8
# 38  ENG-Premier League    2425  2024-09-15 Tottenham Hotspur-Arsenal      4     4
# 49  ENG-Premier League    2425    2024-09-22 Manchester City-Arsenal      5     5
# 10  ENG-Premier League    2425        2024-08-24 Aston Villa-Arsenal      2     2
#
#             home_team away_team  home_score  away_score  p_home_success_score  \
# 70    AFC Bournemouth   Arsenal         2.0         0.0                  7.17
# 38  Tottenham Hotspur   Arsenal         0.0         1.0                  3.88
# 49    Manchester City   Arsenal         2.0         2.0                  5.55
# 10        Aston Villa   Arsenal         0.0         2.0                  3.78
#
#     p_away_success_score  home_success_score  away_success_score predicted_outcome actual_outcome  \
# ...

# %% [markdown]
# # Getafe

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['home_team'] == 'Lens'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_home_success_score'] - df_manchester_united['home_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#           league  season                   game  round  week home_team away_team  home_score  \
# 265  FRA-Ligue 1    2425  2024-10-26 Lens-Lille      9     9      Lens     Lille         0.0
# 242  FRA-Ligue 1    2425   2024-09-28 Lens-Nice      6     6      Lens      Nice         0.0
# 210  FRA-Ligue 1    2425  2024-08-25 Lens-Brest      2     2      Lens     Brest         2.0
# 226  FRA-Ligue 1    2425   2024-09-15 Lens-Lyon      4     4      Lens      Lyon         0.0
#
#      away_score  p_home_success_score  p_away_success_score  home_success_score  \
# 265         2.0                  3.29                  6.71                5.05
# 242         0.0                  5.81                  4.19                4.81
# 210         0.0                  7.15                  2.85                6.25
# 226         0.0                  5.62                  4.38                6.36
#
#      away_success_score predicted_outcome actual_outcome  difference  is_correct
# ...

# %%
# Filter for rows where 'home_team' is 'Manchester United'
df_manchester_united = df[df['away_team'] == 'Lens'].copy()

# Calculate the difference (اختلاف) between 'p_home_success_score' and 'home_success_score'
df_manchester_united['difference'] = abs(df_manchester_united['p_away_success_score'] - df_manchester_united['away_success_score'])

# Sort by the difference in descending order
df_manchester_sorted = df_manchester_united.sort_values(by='difference', ascending=False)

# Display the sorted DataFrame
(df_manchester_sorted).head()
# Out:
#           league  season                        game  round  week   home_team away_team  \
# 234  FRA-Ligue 1    2425      2024-09-21 Rennes-Lens      5     5      Rennes      Lens
# 222  FRA-Ligue 1    2425      2024-09-01 Monaco-Lens      3     3      Monaco      Lens
# 255  FRA-Ligue 1    2425  2024-10-06 Strasbourg-Lens      7     7  Strasbourg      Lens
#
#      home_score  away_score  p_home_success_score  p_away_success_score  home_success_score  \
# 234         1.0         1.0                  5.66                  4.34                4.74
# 222         1.0         1.0                  4.30                  5.70                4.89
# 255         2.0         2.0                  5.11                  4.89                5.51
#
#      away_success_score predicted_outcome actual_outcome  difference  is_correct
# 234                5.26              draw           draw        0.92        True
# 222                5.11              draw           draw        0.59        True
# ...

# %% [markdown]
# # Top

# %%
df.head()
# Out:
#                 league  season                                               game  round  week  \
# 10  ENG-Premier League    2425                     2024-08-24 Aston Villa-Arsenal      2     2
# 11  ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 12  ENG-Premier League    2425          2024-08-24 Crystal Palace-West Ham United      2     2
# 13  ENG-Premier League    2425                   2024-08-24 Fulham-Leicester City      2     2
# 14  ENG-Premier League    2425            2024-08-24 Manchester City-Ipswich Town      2     2
#
#                  home_team          away_team  home_score  away_score  p_home_success_score  \
# 10             Aston Villa            Arsenal         0.0         2.0                  3.78
# 11  Brighton & Hove Albion  Manchester United         2.0         1.0                  5.67
# 12          Crystal Palace    West Ham United         0.0         2.0                  3.65
# ...

# %%
import pandas as pd

# Assuming df is your input DataFrame
# Columns: 'home_team', 'away_team', 'p_home_success_score', 'home_success_score', 
#          'p_away_success_score', 'away_success_score'

# Create dictionaries to store cumulative differences and counts for each team
home_team_totals = {}
home_team_counts = {}
away_team_totals = {}
away_team_counts = {}

# Iterate through rows in the DataFrame
for _, row in df.iterrows():
    # Compute home team differences
    home_difference_1 = row['p_home_success_score'] - row['home_success_score']
    home_difference_2 = row['home_success_score'] - row['p_home_success_score']
    
    # Update cumulative totals and counts for home team
    home_team = row['home_team']
    if home_team not in home_team_totals:
        home_team_totals[home_team] = {'home_difference_1': 0, 'home_difference_2': 0}
        home_team_counts[home_team] = 0
    home_team_totals[home_team]['home_difference_1'] += home_difference_1
    home_team_totals[home_team]['home_difference_2'] += home_difference_2
    home_team_counts[home_team] += 1

    # Compute away team differences
    away_difference_1 = row['p_away_success_score'] - row['away_success_score']
    away_difference_2 = row['away_success_score'] - row['p_away_success_score']
    
    # Update cumulative totals and counts for away team
    away_team = row['away_team']
    if away_team not in away_team_totals:
        away_team_totals[away_team] = {'away_difference_1': 0, 'away_difference_2': 0}
        away_team_counts[away_team] = 0
    away_team_totals[away_team]['away_difference_1'] += away_difference_1
    away_team_totals[away_team]['away_difference_2'] += away_difference_2
    away_team_counts[away_team] += 1

# Compute mean differences for home and away teams
mean_home_results = []
for team, totals in home_team_totals.items():
    mean_home_results.append({
        'team_name': team,
        'mean_home_difference_1': totals['home_difference_1'] / home_team_counts[team],
        'mean_home_difference_2': totals['home_difference_2'] / home_team_counts[team]
    })

mean_away_results = []
for team, totals in away_team_totals.items():
    mean_away_results.append({
        'team_name': team,
        'mean_away_difference_1': totals['away_difference_1'] / away_team_counts[team],
        'mean_away_difference_2': totals['away_difference_2'] / away_team_counts[team]
    })

# Convert results into DataFrames
mean_home_df = pd.DataFrame(mean_home_results)
mean_away_df = pd.DataFrame(mean_away_results)

# Merge home and away mean differences into one DataFrame
final_mean_df = pd.merge(mean_home_df, mean_away_df, on='team_name', how='outer')

# Display the final DataFrame
final_df = final_mean_df

# %%
final_df.tail()
# Out:
#                   team_name  mean_home_difference_1  mean_home_difference_2  \
# 91               Villarreal                0.562500               -0.562500
# 92            Werder Bremen               -0.073333                0.073333
# 93          West Ham United               -0.452500                0.452500
# 94                Wolfsburg               -0.236667                0.236667
# 95  Wolverhampton Wanderers                0.010000               -0.010000
#
#     mean_away_difference_1  mean_away_difference_2
# 91                1.093333               -1.093333
# 92                0.280000               -0.280000
# 93                0.777500               -0.777500
# 94                0.850000               -0.850000
# 95                0.837500               -0.837500

# %%
df_combined = final_df

# %%
# Napoli		1.246000	
# Milan	0.764167	-0.764167
# Chelsea		0.660000
# Bayern München	2.088333	
# Barcelona	1.061667	



# Atletico Madrid	-0.920000
# Manchester United	-0.923333
# Roma	-1.307500
# Manchester City	-1.233333
# Bayer Leverkusen	-1.235000

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
teams = [
    'Napoli', 'Milan', 'Chelsea', 'Bayern München', 'Barcelona',
    'Atletico Madrid', 'Manchester United', 'Roma', 'Manchester City', 'Bayer Leverkusen'
]
values = [
    1.246000, 0.764167, 0.660000, 2.088333, 1.061667,
    -0.920000, -0.923333, -1.307500, -1.233333, -1.235000
]

# Assign colors based on positive or negative values
colors = ['#4CAF50' if val > 0 else '#F44336' for val in values]  # Green for positive, Red for negative

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
ax = plt.gca()

# Plot horizontal bars
bars = ax.barh(teams, values, color=colors, edgecolor='white', height=0.7)

# Add a vertical line at x=0 to separate positive and negative values
ax.axvline(x=0, color='black', linewidth=0.8)

# Add team names and values inside the bars
for bar, team, value in zip(bars, teams, values):
    width = bar.get_width()
    # Adjust label position based on whether value is positive or negative
    if width > 0:
        ax.text(width - 0.05, bar.get_y() + bar.get_height()/2, team,
                va='center', ha='right', fontsize=12, color='black')
        ax.text(width + 0.1, bar.get_y() + bar.get_height()/2, f'{value:.3f}',
                va='center', ha='left', fontsize=7, color='black')  # Smaller and non-bold
    else:
        ax.text(width + 0.05, bar.get_y() + bar.get_height()/2, team,
                va='center', ha='left', fontsize=12, color='black')
        ax.text(width - 0.1, bar.get_y() + bar.get_height()/2, f'{value:.3f}',
                va='center', ha='right', fontsize=7, color='black')  # Smaller and non-bold

# Customize the plot
ax.set_xlabel('Mean Difference of Predicted Success Scores', fontsize=14, fontweight='bold', labelpad=20)
ax.set_title('Team Performance Comparison', fontsize=16, fontweight='bold', pad=10)

# Remove y-axis labels (team names will be placed inside bars)
ax.set_yticks([])

# Remove unnecessary spines and improve appearance
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(True)

# Add subtle gridlines only on the x-axis for clarity
ax.xaxis.grid(True, linestyle='--', alpha=0.3, which='major', color='gray')

# Set x-axis limits to ensure that the negative and positive sides have equal space
ax.set_xlim(-max(abs(np.array(values))), max(abs(np.array(values))))

# Improve layout for better spacing and prevent clipping
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Add new columns
df_combined['sum_difference_1'] = df_combined['mean_home_difference_1'] + df_combined['mean_away_difference_1']
df_combined['sum_difference_2'] = df_combined['mean_home_difference_2'] + df_combined['mean_away_difference_2']

# Sort by one of the new columns, e.g., 'sum_difference_1'
df_combined_sorted = df_combined.sort_values(by='sum_difference_1', ascending=False).reset_index(drop=True)

df_combined_sorted.head(50)
# Out:
#                   team_name  mean_home_difference_1  mean_home_difference_2  \
# 0                Fiorentina            5.820000e-01           -5.820000e-01
# 1       Eintracht Frankfurt            1.410000e+00           -1.410000e+00
# 2            Bayern München            1.083333e+00           -1.083333e+00
# 3                   Udinese            1.514000e+00           -1.514000e+00
# 4                    Fulham            6.950000e-01           -6.950000e-01
# 5                Strasbourg            1.164000e+00           -1.164000e+00
# 6                Villarreal            5.625000e-01           -5.625000e-01
# 7                    Torino            1.325000e-01           -1.325000e-01
# 8                Real Betis            1.262000e+00           -1.262000e+00
# 9                    Napoli            3.360000e-01           -3.360000e-01
# 10             Union Berlin            3.900000e-01           -3.900000e-01
# ...

# %%
df_combined_sorted.tail(50)
# Out:
#                    team_name  mean_home_difference_1  mean_home_difference_2  \
# 46                  Valencia                1.050000               -1.050000
# 47                     Brest                0.565000               -0.565000
# 48               Real Madrid               -0.716667                0.716667
# 49                      Lens               -0.150000                0.150000
# 50            Rayo Vallecano                0.250000               -0.250000
# 51                      Como               -0.036667                0.036667
# 52          Deportivo Alaves               -0.646000                0.646000
# 53           Real Valladolid               -0.160000                0.160000
# 54                  Mainz 05               -0.915000                0.915000
# 55             VfB Stuttgart               -0.097500                0.097500
# 56                   Venezia                0.123333               -0.123333
# ...

# %%
import pandas as pd
predicted_results_df = predicted_results
def determine_prediction(home_success_score, away_success_score):
    if 4.6 <= home_success_score <= 5.2:
        return 'draw'
    elif home_success_score > 5.2:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score']), axis=1
)

# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate the number of correct predictions
correct_predictions = (predicted_results_df['predicted_outcome'] == predicted_results_df['actual_outcome']).sum()

# Display the number of correct predictions
print(f"Number of correct predictions: {correct_predictions}")
# Out:
# Number of correct predictions: 173

# %%
# 5 - 2 - 207 
# 3 - 2 - 221

# %%
# predicted_results_df = predicted_results_df[predicted_results_df["league"] != "GER-Bundesliga"]

# %%
predicted_results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382 entries, 10 to 429
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   league                382 non-null    object
#  1   season                382 non-null    int64
#  2   game                  382 non-null    object
#  3   round                 382 non-null    int64
#  4   week                  382 non-null    int64
#  5   home_team             382 non-null    object
#  6   away_team             382 non-null    object
#  7   home_score            382 non-null    float64
#  8   away_score            382 non-null    float64
#  9   p_home_success_score  382 non-null    float64
#  10  p_away_success_score  382 non-null    float64
#  11  home_success_score    382 non-null    float64
#  12  away_success_score    382 non-null    float64
#  13  predicted_outcome     382 non-null    object
#  14  actual_outcome        382 non-null    object
# ...

# %%
# From 257

# %%
import pandas as pd



# Define the prediction outcomes based on success scores
def determine_prediction(home_success_score, away_success_score):
    if 4.6 <= home_success_score <=  5.2:
        return 'draw'
    elif home_success_score > 5.2:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score']), axis=1
)

# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate correct predictions
predicted_results_df['is_correct'] = predicted_results_df['predicted_outcome'] == predicted_results_df['actual_outcome']

# Group by league and calculate stats
league_stats = predicted_results_df.groupby('league').agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)

# Calculate the accuracy percentage for each league
league_stats['accuracy_percentage'] = (league_stats['correct_predictions'] / league_stats['total_games']) * 100

# Display the results
print("Prediction Accuracy by League:")
print(league_stats)
# Out:
# Prediction Accuracy by League:
#                     total_games  correct_predictions  accuracy_percentage
# league
# ENG-Premier League           80                   35            43.750000
# ESP-La Liga                  99                   46            46.464646
# FRA-Ligue 1                  64                   28            43.750000
# GER-Bundesliga               61                   28            45.901639
# ITA-Serie A                  78                   36            46.153846

# %%
predicted_results_df["league"].unique()
# Out:
# array(['ENG-Premier League', 'ESP-La Liga', 'FRA-Ligue 1',
#        'GER-Bundesliga', 'ITA-Serie A'], dtype=object)

# %%
import pandas as pd

# Assuming predicted_results_df is already loaded
def determine_prediction(home_success_score, away_success_score):
    if 4.6<= home_success_score <= 5.2:
        return 'draw'
    elif home_success_score > 5.2:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score']), axis=1
)

# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate correct predictions based on the new criteria
def is_prediction_correct(predicted, actual):
    if predicted == 'home_win' or predicted == 'draw':
        return actual != 'away_win'  # Correct if actual outcome is not an away win
    elif predicted == 'away_win':
        return actual != 'home_win'  # Correct if actual outcome is not a home win
    return False  # Any other cases are considered incorrect

# Apply the custom correctness function to determine if predictions are correct
predicted_results_df['is_correct'] = predicted_results_df.apply(
    lambda row: is_prediction_correct(row['predicted_outcome'], row['actual_outcome']), axis=1
)

# Group by league and round and calculate stats
round_stats = predicted_results_df.groupby(['league', 'round']).agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)

# Calculate the accuracy percentage for each league and round
round_stats['accuracy_percentage'] = (round_stats['correct_predictions'] / round_stats['total_games']) * 100

# Display the results for each round
for league, round_data in round_stats.groupby(level=0):  # Group by league
    print(f"Prediction Accuracy for {league}:")
    print(round_data)  # Prints the data for each round in the league
    print("\n")

# Calculate and display the total accuracy for each league
league_stats = predicted_results_df.groupby('league').agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)
league_stats['total_accuracy_percentage'] = (league_stats['correct_predictions'] / league_stats['total_games']) * 100

print("Total Accuracy for Each League:")
print(league_stats[['total_accuracy_percentage']])
# Out:
# Prediction Accuracy for ENG-Premier League:
#                           total_games  correct_predictions  accuracy_percentage
# league             round
# ENG-Premier League 2               10                    8                 80.0
#                    3               10                    7                 70.0
#                    4               10                    5                 50.0
#                    5               10                    9                 90.0
#                    6               10                    8                 80.0
#                    7               10                    9                 90.0
#                    8               10                    6                 60.0
#                    9               10                    9                 90.0
#
#
# Prediction Accuracy for ESP-La Liga:
#                    total_games  correct_predictions  accuracy_percentage
# league      round
# ...

# %%
# Group by the round across all leagues and calculate combined stats
combined_round_stats = predicted_results_df.groupby('round').agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)
print("lose - not_lose")
# Calculate the combined accuracy percentage for each round
combined_round_stats['accuracy_percentage'] = (combined_round_stats['correct_predictions'] / combined_round_stats['total_games']) * 100

# Display the combined results for each week across all leagues
print("Combined Prediction Accuracy Across All Leagues by Week:")
counter = 0
for round_num, row in combined_round_stats.iterrows():
    total_games = row['total_games']
    correct_predictions = row['correct_predictions']
    accuracy_percentage = row['accuracy_percentage']
    counter = counter + correct_predictions
    print(f"  Week {round_num}: {correct_predictions} out of {total_games} correct ({accuracy_percentage:.2f}%)")

print(f"Total Correct Predictions: {counter} out of {combined_round_stats['total_games'].sum()} ({(counter / combined_round_stats['total_games'].sum()) * 100:.2f}%)")
# Out:
# lose - not_lose
# Combined Prediction Accuracy Across All Leagues by Week:
#   Week 2: 34.0 out of 46.0 correct (73.91%)
#   Week 3: 33.0 out of 48.0 correct (68.75%)
#   Week 4: 33.0 out of 45.0 correct (73.33%)
#   Week 5: 34.0 out of 48.0 correct (70.83%)
#   Week 6: 34.0 out of 46.0 correct (73.91%)
#   Week 7: 42.0 out of 47.0 correct (89.36%)
#   Week 8: 35.0 out of 46.0 correct (76.09%)
#   Week 9: 31.0 out of 37.0 correct (83.78%)
#   Week 10: 7.0 out of 10.0 correct (70.00%)
#   Week 11: 4.0 out of 9.0 correct (44.44%)
# Total Correct Predictions: 287.0 out of 382 (75.13%)

# %%
import pandas as pd

# Assuming predicted_results_df is already loaded
def determine_prediction(home_success_score, away_success_score):
    if 4.6 <= home_success_score <= 5.2:
        return 'draw'
    elif home_success_score > 5.2:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score']), axis=1
)

# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate correct predictions based on the new criteria
def is_prediction_correct(predicted, actual):
    if predicted == 'away_win' or predicted == 'draw':
        return actual != 'home_win'  # Correct if actual outcome is not an away win
    elif predicted == 'home_win':
        return actual != 'away_win'  # Correct if actual outcome is not a home win
    return False  # Any other cases are considered incorrect

# Apply the custom correctness function to determine if predictions are correct
predicted_results_df['is_correct'] = predicted_results_df.apply(
    lambda row: is_prediction_correct(row['predicted_outcome'], row['actual_outcome']), axis=1
)

# Group by league and round and calculate stats
round_stats = predicted_results_df.groupby(['league', 'round']).agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)

# Calculate the accuracy percentage for each league and round
round_stats['accuracy_percentage'] = (round_stats['correct_predictions'] / round_stats['total_games']) * 100

# Display the results for each round
for league, round_data in round_stats.groupby(level=0):  # Group by league
    print(f"Prediction Accuracy for {league}:")
    print(round_data)  # Prints the data for each round in the league
    print("\n")

# Calculate and display the total accuracy for each league
league_stats = predicted_results_df.groupby('league').agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)
league_stats['total_accuracy_percentage'] = (league_stats['correct_predictions'] / league_stats['total_games']) * 100

print("Total Accuracy for Each League:")
print(league_stats[['total_accuracy_percentage']])
# Out:
# Prediction Accuracy for ENG-Premier League:
#                           total_games  correct_predictions  accuracy_percentage
# league             round
# ENG-Premier League 2               10                    7                 70.0
#                    3               10                    8                 80.0
#                    4               10                    7                 70.0
#                    5               10                    9                 90.0
#                    6               10                    6                 60.0
#                    7               10                    8                 80.0
#                    8               10                    6                 60.0
#                    9               10                    7                 70.0
#
#
# Prediction Accuracy for ESP-La Liga:
#                    total_games  correct_predictions  accuracy_percentage
# league      round
# ...

# %%
# Group by the round across all leagues and calculate combined stats
combined_round_stats = predicted_results_df.groupby('round').agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)
print("win - notwin")
# Calculate the combined accuracy percentage for each round
combined_round_stats['accuracy_percentage'] = (combined_round_stats['correct_predictions'] / combined_round_stats['total_games']) * 100

# Display the combined results for each week across all leagues
print("Combined Prediction Accuracy Across All Leagues by Week:")
counter = 0
for round_num, row in combined_round_stats.iterrows():
    total_games = row['total_games']
    correct_predictions = row['correct_predictions']
    accuracy_percentage = row['accuracy_percentage']
    counter = counter + correct_predictions
    print(f"  Week {round_num}: {correct_predictions} out of {total_games} correct ({accuracy_percentage:.2f}%)")

print(f"Total Correct Predictions: {counter} out of {combined_round_stats['total_games'].sum()} ({(counter / combined_round_stats['total_games'].sum()) * 100:.2f}%)")
# Out:
# win - notwin
# Combined Prediction Accuracy Across All Leagues by Week:
#   Week 2: 31.0 out of 46.0 correct (67.39%)
#   Week 3: 32.0 out of 48.0 correct (66.67%)
#   Week 4: 35.0 out of 45.0 correct (77.78%)
#   Week 5: 33.0 out of 48.0 correct (68.75%)
#   Week 6: 34.0 out of 46.0 correct (73.91%)
#   Week 7: 42.0 out of 47.0 correct (89.36%)
#   Week 8: 35.0 out of 46.0 correct (76.09%)
#   Week 9: 27.0 out of 37.0 correct (72.97%)
#   Week 10: 8.0 out of 10.0 correct (80.00%)
#   Week 11: 3.0 out of 9.0 correct (33.33%)
# Total Correct Predictions: 280.0 out of 382 (73.30%)

# %%
import pandas as pd

# Function to determine prediction based on league-specific ranges
def determine_prediction(home_success_score, away_success_score, league):
    if league == 'GER-Bundesliga':
        if 3.9 <= home_success_score <= 5.55:
            return 'draw'
        elif home_success_score > 5.55:
            return 'home_win'
        else:
            return 'away_win'
    elif league == 'ITA-Serie A':
        if 3.9 <= home_success_score <= 6.15:
            return 'draw'
        elif home_success_score > 6.15:
            return 'home_win'
        else:
            return 'away_win'
    elif league == 'ESP-La Liga':
        if 3.9 <= home_success_score <= 5.75:
            return 'draw'
        elif home_success_score > 5.75:
            return 'home_win'
        else:
            return 'away_win'
    elif league == 'ENG-Premier League':
        if 3.9 <= home_success_score <= 5.85:
            return 'draw'
        elif home_success_score > 5.85:
            return 'home_win'
        else:
            return 'away_win'
    elif league == 'FRA-Ligue 1':
        if 3.9 <= home_success_score <= 5.85:
            return 'draw'
        elif home_success_score > 5.85:
            return 'home_win'
        else:
            return 'away_win'
    

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score'], row['league']), axis=1
)


# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate correct predictions based on the new criteria
def is_prediction_correct(predicted, actual):
    if predicted == 'home_win' or predicted == 'draw':
        return actual != 'away_win'  # Correct if actual outcome is not an away win
    elif predicted == 'away_win':
        return actual != 'home_win'  # Correct if actual outcome is not a home win
    return False  # Any other cases are considered incorrect

# Apply the custom correctness function to determine if predictions are correct
predicted_results_df['is_correct'] = predicted_results_df.apply(
    lambda row: is_prediction_correct(row['predicted_outcome'], row['actual_outcome']), axis=1
)

# Group by league and round and calculate stats
round_stats = predicted_results_df.groupby(['league', 'round']).agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)

# Calculate the accuracy percentage for each league and round
round_stats['accuracy_percentage'] = (round_stats['correct_predictions'] / round_stats['total_games']) * 100

# Display the results for each round
for league, round_data in round_stats.groupby(level=0):  # Group by league
    print(f"Prediction Accuracy for {league}:")
    print(round_data)  # Prints the data for each round in the league
    print("\n")
# Out:
# Prediction Accuracy for ENG-Premier League:
#                           total_games  correct_predictions  accuracy_percentage
# league             round
# ENG-Premier League 2               10                    6                 60.0
#                    3               10                    6                 60.0
#                    4               10                    5                 50.0
#                    5               10                    9                 90.0
#                    6               10                    7                 70.0
#                    7               10                    9                 90.0
#                    8               10                    5                 50.0
#                    9               10                    9                 90.0
#
#
# Prediction Accuracy for ESP-La Liga:
#                    total_games  correct_predictions  accuracy_percentage
# league      round
# ...

# %%
import pandas as pd

# Assuming predicted_results_df is already loaded

def determine_prediction(home_success_score, away_success_score):
    if 3.8 <= home_success_score <= 5.9:
        return 'draw'
    elif home_success_score > 5.9:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score']), axis=1
)

# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate correct predictions based on strict matching of prediction to actual outcome
def is_prediction_correct(predicted, actual):
    return predicted == actual  # Correct only if predicted outcome matches actual outcome exactly

# Apply the custom correctness function to determine if predictions are correct
predicted_results_df['is_correct'] = predicted_results_df.apply(
    lambda row: is_prediction_correct(row['predicted_outcome'], row['actual_outcome']), axis=1
)

# Group by league and round and calculate stats
round_stats = predicted_results_df.groupby(['league', 'round']).agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)

# Calculate the accuracy percentage for each league and round
round_stats['accuracy_percentage'] = (round_stats['correct_predictions'] / round_stats['total_games']) * 100

# Display the results for each round
for league, round_data in round_stats.groupby(level=0):  # Group by league
    print(f"Prediction Accuracy for {league}:")
    print(round_data)  # Prints the data for each round in the league
    print("\n")
# Out:
# Prediction Accuracy for ENG-Premier League:
#                           total_games  correct_predictions  accuracy_percentage
# league             round
# ENG-Premier League 2               10                    3                 30.0
#                    3               10                    2                 20.0
#                    4               10                    4                 40.0
#                    5               10                    4                 40.0
#                    6               10                    4                 40.0
#                    7               10                    5                 50.0
#                    8               10                    3                 30.0
#                    9               10                    2                 20.0
#
#
# Prediction Accuracy for ESP-La Liga:
#                    total_games  correct_predictions  accuracy_percentage
# league      round
# ...

# %%
import pandas as pd

# Assuming predicted_results_df is already loaded

def determine_prediction(home_success_score, away_success_score):
    if 3.95 <= home_success_score <= 5.2:
        return 'draw'
    elif home_success_score > 5.2:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score']), axis=1
)

# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate correct predictions based on strict matching of prediction to actual outcome
predicted_results_df['is_correct'] = predicted_results_df.apply(
    lambda row: row['predicted_outcome'] == row['actual_outcome'], axis=1
)

# Group by league and round and calculate stats
round_stats = predicted_results_df.groupby(['league', 'round']).agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)

# Calculate the accuracy percentage for each league and round
round_stats['accuracy_percentage'] = (round_stats['correct_predictions'] / round_stats['total_games']) * 100

# Display the weeks (rounds), correct predictions, and percentages
for (league, round_num), row in round_stats.iterrows():
    print(f"League: {league}, Round: {round_num}")
    print(f"Correct Predictions: {row['correct_predictions']}, Total Games: {row['total_games']}")
    print(f"Accuracy: {row['accuracy_percentage']:.2f}%")
    print("-" * 40)
# Out:
# League: ENG-Premier League, Round: 2
# Correct Predictions: 4.0, Total Games: 10.0
# Accuracy: 40.00%
# ----------------------------------------
# League: ENG-Premier League, Round: 3
# Correct Predictions: 5.0, Total Games: 10.0
# Accuracy: 50.00%
# ----------------------------------------
# League: ENG-Premier League, Round: 4
# Correct Predictions: 2.0, Total Games: 10.0
# Accuracy: 20.00%
# ----------------------------------------
# League: ENG-Premier League, Round: 5
# Correct Predictions: 4.0, Total Games: 10.0
# Accuracy: 40.00%
# ----------------------------------------
# League: ENG-Premier League, Round: 6
# Correct Predictions: 4.0, Total Games: 10.0
# Accuracy: 40.00%
# ----------------------------------------
# League: ENG-Premier League, Round: 7
# Correct Predictions: 4.0, Total Games: 10.0
# Accuracy: 40.00%
# ----------------------------------------
# League: ENG-Premier League, Round: 8
# Correct Predictions: 5.0, Total Games: 10.0
# Accuracy: 50.00%
# ...

# %%
predicted_results_df[predicted_results_df["week"] == 9]
# Out:
#                  league  season                                               game  round  week  \
# 80   ENG-Premier League    2425        2024-10-25 Leicester City-Nottingham Forest      9     9
# 81   ENG-Premier League    2425             2024-10-26 Aston Villa-AFC Bournemouth      9     9
# 82   ENG-Premier League    2425                  2024-10-26 Brentford-Ipswich Town      9     9
# 83   ENG-Premier League    2425  2024-10-26 Brighton & Hove Albion-Wolverhampto...      9     9
# 84   ENG-Premier League    2425                          2024-10-26 Everton-Fulham      9     9
# 85   ENG-Premier League    2425             2024-10-26 Manchester City-Southampton      9     9
# 86   ENG-Premier League    2425                       2024-10-27 Arsenal-Liverpool      9     9
# 87   ENG-Premier League    2425                2024-10-27 Chelsea-Newcastle United      9     9
# 88   ENG-Premier League    2425        2024-10-27 Crystal Palace-Tottenham Hotspur      9     9
# ...

# %%
import pandas as pd

# Assuming predicted_results_df is already loaded

import pandas as pd
predicted_results_df = predicted_results
# Define the prediction outcomes based on success scores
def determine_prediction(home_success_score, away_success_score):
    if 3.95 <= home_success_score <= 5.2:
        return 'draw'
    elif home_success_score > 5.2:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine predicted outcomes
predicted_results_df['predicted_outcome'] = predicted_results_df.apply(
    lambda row: determine_prediction(row['home_success_score'], row['away_success_score']), axis=1
)

# Define the actual outcome based on home and away scores
def determine_actual(home_score, away_score):
    if home_score == away_score:
        return 'draw'
    elif home_score > away_score:
        return 'home_win'
    else:
        return 'away_win'

# Apply function to determine actual outcomes
predicted_results_df['actual_outcome'] = predicted_results_df.apply(
    lambda row: determine_actual(row['home_score'], row['away_score']), axis=1
)

# Calculate correct predictions based on strict matching of prediction to actual outcome
predicted_results_df['is_correct'] = predicted_results_df.apply(
    lambda row: row['predicted_outcome'] == row['actual_outcome'], axis=1
)

# Group by round (week) and calculate stats across all leagues
week_stats = predicted_results_df.groupby('round').agg(
    total_games=('game', 'size'),
    correct_predictions=('is_correct', 'sum')
)

# Calculate the accuracy percentage for each round
week_stats['accuracy_percentage'] = (week_stats['correct_predictions'] / week_stats['total_games']) * 100

# Display the stats for each week
for round_num, row in week_stats.iterrows():
    print(f"Week: {round_num}")
    print(f"Correct Predictions: {row['correct_predictions']}, Total Games: {row['total_games']}")
    print(f"Accuracy: {row['accuracy_percentage']:.2f}%")
    print("-" * 40)
# Out:
# Week: 2
# Correct Predictions: 19.0, Total Games: 46.0
# Accuracy: 41.30%
# ----------------------------------------
# Week: 3
# Correct Predictions: 18.0, Total Games: 48.0
# Accuracy: 37.50%
# ----------------------------------------
# Week: 4
# Correct Predictions: 19.0, Total Games: 45.0
# Accuracy: 42.22%
# ----------------------------------------
# Week: 5
# Correct Predictions: 18.0, Total Games: 48.0
# Accuracy: 37.50%
# ----------------------------------------
# Week: 6
# Correct Predictions: 15.0, Total Games: 46.0
# Accuracy: 32.61%
# ----------------------------------------
# Week: 7
# Correct Predictions: 26.0, Total Games: 47.0
# Accuracy: 55.32%
# ----------------------------------------
# Week: 8
# Correct Predictions: 24.0, Total Games: 46.0
# Accuracy: 52.17%
# ----------------------------------------
# Week: 9
# Correct Predictions: 15.0, Total Games: 37.0
# Accuracy: 40.54%
# ----------------------------------------
# Week: 10
# ...

# %%
t = predicted_results_df[predicted_results_df["week"] == 10]
t.head(20)
# Out:
#           league  season                                         game  round  week  \
# 180  ESP-La Liga    2425  2024-10-18 Deportivo Alaves-Real Valladolid     10    10
# 181  ESP-La Liga    2425            2024-10-19 Athletic Club-Espanyol     10    10
# 182  ESP-La Liga    2425            2024-10-19 Celta Vigo-Real Madrid     10    10
# 183  ESP-La Liga    2425              2024-10-19 Girona-Real Sociedad     10    10
# 184  ESP-La Liga    2425                2024-10-19 Osasuna-Real Betis     10    10
# 185  ESP-La Liga    2425           2024-10-20 Atletico Madrid-Leganes     10    10
# 186  ESP-La Liga    2425                 2024-10-20 Barcelona-Sevilla     10    10
# 187  ESP-La Liga    2425           2024-10-20 Mallorca-Rayo Vallecano     10    10
# 188  ESP-La Liga    2425                 2024-10-20 Villarreal-Getafe     10    10
# 189  ESP-La Liga    2425               2024-10-21 Valencia-Las Palmas     10    10
#
# ...

# %%
# match_result       Draw       Loss        Win
# score_range                                  
# 0-1            4.000000  96.000000   0.000000
# 1-2            3.641457  96.358543   0.000000
# 2-3            8.936170  91.063830   0.000000
# 3-4           18.228279  81.090290   0.681431
# 4-5           52.535761  39.921977   7.542263
# 5-6           57.497182   8.793687  33.709132
# 6-7           30.376671   1.458080  68.165249
# 7-8            9.752547   0.000000  90.247453
# 8-9            7.342657   0.000000  92.657343
# 9-10           2.827763   0.000000  97.172237

# %%
df.head()
# Out:
#                 league  season                                               game  round  week  \
# 10  ENG-Premier League    2425                     2024-08-24 Aston Villa-Arsenal      2     2
# 11  ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 12  ENG-Premier League    2425          2024-08-24 Crystal Palace-West Ham United      2     2
# 13  ENG-Premier League    2425                   2024-08-24 Fulham-Leicester City      2     2
# 14  ENG-Premier League    2425            2024-08-24 Manchester City-Ipswich Town      2     2
#
#                  home_team          away_team  home_score  away_score  p_home_success_score  \
# 10             Aston Villa            Arsenal         0.0         2.0                  3.78
# 11  Brighton & Hove Albion  Manchester United         2.0         1.0                  5.67
# 12          Crystal Palace    West Ham United         0.0         2.0                  3.65
# ...

# %%
predicted_results_df
# Out:
#                  league  season                                               game  round  week  \
# 10   ENG-Premier League    2425                     2024-08-24 Aston Villa-Arsenal      2     2
# 11   ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 12   ENG-Premier League    2425          2024-08-24 Crystal Palace-West Ham United      2     2
# 13   ENG-Premier League    2425                   2024-08-24 Fulham-Leicester City      2     2
# 14   ENG-Premier League    2425            2024-08-24 Manchester City-Ipswich Town      2     2
# ..                  ...     ...                                                ...    ...   ...
# 425         ITA-Serie A    2425                         2024-10-27 Fiorentina-Roma      9     9
# 426         ITA-Serie A    2425                          2024-10-27 Inter-Juventus      9     9
# 427         ITA-Serie A    2425                             2024-10-27 Lazio-Genoa      9     9
# ...

# %%
df = predicted_results_df

# %%
df.shape[0]
# Out:
# 382

# %%
import pandas as pd

# Count rows for the first condition
condition1 = (df['home_success_score'] > df['away_success_score']) & \
             (df['actual_outcome'].isin(['draw', 'home_win']))
count_condition1 = df[condition1].shape[0]

# Count rows for the second condition
condition2 = (df['home_success_score'] < df['away_success_score']) & \
             (df['actual_outcome'] == 'away_win')
count_condition2 = df[condition2].shape[0]

print("Number of rows for condition 1:", count_condition1)
print("Number of rows for condition 2:", count_condition2)
# Out:
# Number of rows for condition 1: 189
# Number of rows for condition 2: 58

# %%
# Calculate total count
total_count = count_condition1 + count_condition2

# Create a combined DataFrame
result_df = pd.DataFrame({
    'Condition': ['Condition 1', 'Condition 2', 'Total'],
    'Count': [count_condition1, count_condition2, total_count]
})

# %%
print(total_count/df.shape[0])
# Out:
# 0.6465968586387435

# %%
result_df.head()
# Out:
#      Condition  Count
# 0  Condition 1    189
# 1  Condition 2     58
# 2        Total    247

# %%
# Filter rows for the first condition
condition1 = (df['home_success_score'] > df['away_success_score']) & \
             (df['actual_outcome'].isin(['draw', 'home_win']))
filtered_condition1 = df[condition1]

# Filter rows for the second condition
condition2 = (df['home_success_score'] < df['away_success_score']) & \
             (df['actual_outcome'] == 'away_win')
filtered_condition2 = df[condition2]

# Combine rows satisfying both conditions
combined_df = pd.concat([filtered_condition1, filtered_condition2]).reset_index(drop=True)

# %%
combined_df.head(100)
# Out:
#                 league  season                                               game  round  week  \
# 0   ENG-Premier League    2425  2024-08-24 Brighton & Hove Albion-Manchester U...      2     2
# 1   ENG-Premier League    2425                   2024-08-24 Fulham-Leicester City      2     2
# 2   ENG-Premier League    2425            2024-08-24 Manchester City-Ipswich Town      2     2
# 3   ENG-Premier League    2425               2024-08-24 Tottenham Hotspur-Everton      2     2
# 4   ENG-Premier League    2425        2024-08-25 AFC Bournemouth-Newcastle United      2     2
# 5   ENG-Premier League    2425                     2024-08-25 Liverpool-Brentford      2     2
# 6   ENG-Premier League    2425          2024-08-31 Arsenal-Brighton & Hove Albion      3     3
# 7   ENG-Premier League    2425  2024-08-31 Nottingham Forest-Wolverhampton Wan...      3     3
# 8   ENG-Premier League    2425      2024-09-01 Newcastle United-Tottenham Hotspur      3     3
# ...

# %% [markdown]
# # END
