# %%
import pandas as pd

# %%
data = pd.read_csv('male_players.csv')
# Out:
# /var/folders/_q/9q3nkf795kx68k9vjkj8hps80000gn/T/ipykernel_82130/1747293251.py:1: DtypeWarning: Columns (108) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('male_players.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
data["fifa_version"].unique()
# Out:
# array([24., 23., 22., 21., 20., 19., 18., 17., 16., 15.])

# %%
import pandas as pd

# Load your data into a DataFrame
# Example: df = pd.read_csv('your_data_file.csv')

# Define the list of columns to keep
columns_to_keep = [
    'fifa_version', 'short_name', 'long_name', 'player_positions', 'overall', 'potential', 'age',
    'club_name', 'league_name', 'club_position',
    'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
    'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys',
    'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
    'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance',
    'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
    'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure',
    'defending_marking_awareness', 'defending_standing_tackle', 'defending_sliding_tackle',
    'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed',
    'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb', 'gk'
]

# Filter the DataFrame to keep only the desired columns
data = data[columns_to_keep]
data.head()
# Out:
#    fifa_version    short_name                       long_name  \
# 0          24.0     K. Mbappé            Kylian Mbappé Lottin
# 1          24.0    E. Haaland            Erling Braut Haaland
# 2          24.0  K. De Bruyne                 Kevin De Bruyne
# 3          24.0      L. Messi  Lionel Andrés Messi Cuccittini
# 4          24.0    K. Benzema                   Karim Benzema
#
#   player_positions  overall  potential  age            club_name  \
# 0           ST, LW       91         94   24  Paris Saint Germain
# 1               ST       91         94   22      Manchester City
# 2          CM, CAM       91         91   32      Manchester City
# 3          CF, CAM       90         90   36          Inter Miami
# 4           CF, ST       90         90   35           Al Ittihad
#
#            league_name club_position  pace  shooting  passing  dribbling  \
# 0              Ligue 1            LW  97.0      90.0     80.0       92.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180021 entries, 0 to 180020
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   fifa_version                 180021 non-null  float64
#  1   short_name                   180021 non-null  object
#  2   long_name                    180021 non-null  object
#  3   player_positions             180021 non-null  object
#  4   overall                      180021 non-null  int64
#  5   potential                    180021 non-null  int64
#  6   age                          180021 non-null  int64
#  7   club_name                    178156 non-null  object
#  8   league_name                  178156 non-null  object
#  9   club_position                178156 non-null  object
#  10  pace                         159997 non-null  float64
#  11  shooting                     159997 non-null  float64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
import pandas as pd

df = data 
df['player_positions_split'] = df['player_positions'].str.split(', ')

# Convert list of positions into separate columns
positions_df = pd.DataFrame(df['player_positions_split'].tolist())

# Rename columns to 'position_1', 'position_2', etc.
positions_df.columns = [f'position_{i+1}' for i in range(positions_df.shape[1])]

# Concatenate the new columns back to the original DataFrame
df = pd.concat([df, positions_df], axis=1)

# Drop the original 'player_positions_split' column
df = df.drop(columns=['player_positions_split'])

df.head()
data = df

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180021 entries, 0 to 180020
# Data columns (total 82 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   fifa_version                 180021 non-null  float64
#  1   short_name                   180021 non-null  object
#  2   long_name                    180021 non-null  object
#  3   player_positions             180021 non-null  object
#  4   overall                      180021 non-null  int64
#  5   potential                    180021 non-null  int64
#  6   age                          180021 non-null  int64
#  7   club_name                    178156 non-null  object
#  8   league_name                  178156 non-null  object
#  9   club_position                178156 non-null  object
#  10  pace                         159997 non-null  float64
#  11  shooting                     159997 non-null  float64
# ...

# %%
# Define function to calculate ratings based on attributes
def calculate_tactical_rating(row, weights):
    total = sum(row[att] * weight for att, weight in weights.items())
    return round(total,0)

# %%
data.head(10)
# Out:
#    fifa_version      short_name                                long_name  \
# 0          24.0       K. Mbappé                     Kylian Mbappé Lottin
# 1          24.0      E. Haaland                     Erling Braut Haaland
# 2          24.0    K. De Bruyne                          Kevin De Bruyne
# 3          24.0        L. Messi           Lionel Andrés Messi Cuccittini
# 4          24.0      K. Benzema                            Karim Benzema
# 5          24.0  R. Lewandowski                       Robert Lewandowski
# 6          24.0     T. Courtois            Thibaut Nicolas Marc Courtois
# 7          24.0         H. Kane                               Harry Kane
# 8          24.0        Vini Jr.  Vinícius José Paixão de Oliveira Júnior
# 9          24.0         Alisson                    Alisson Ramsés Becker
#
#   player_positions  overall  potential  age            club_name  \
# 0           ST, LW       91         94   24  Paris Saint Germain
# ...

# %% [markdown]
# # Possession Play

# %%
# Define the weights for each position with 0.1 weight for each feature
weights_dict = {
    'striker': {
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'movement_agility': 0.1,
        'skill_ball_control': 0.1,
        'mentality_composure': 0.1,
        'skill_dribbling': 0.1,
        'attacking_heading_accuracy': 0.1,
        'mentality_positioning': 0.1,
        'power_shot_power': 0.1,
        'pace': 0.1
    },
    'center_forward': {
        'attacking_short_passing': 0.1,
        'skill_ball_control': 0.1,
        'movement_balance': 0.1,
        'attacking_finishing': 0.1,
        'skill_dribbling': 0.1,
        'mentality_composure': 0.1,
        'pace': 0.1,
        'movement_reactions': 0.1,
        'power_long_shots': 0.1,
        'attacking_crossing': 0.1
    },
    'winger': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'pace': 0.1,
        'attacking_short_passing': 0.1,
        'skill_ball_control': 0.1,
        'movement_acceleration': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'skill_curve': 0.1,
        'power_stamina': 0.1
    },
    'attacking_midfielder': {
        'passing': 0.1,
        'skill_dribbling': 0.1,
        'mentality_vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_ball_control': 0.1,
        'mentality_composure': 0.1,
        'movement_reactions': 0.1,
        'attacking_finishing': 0.1,
        'skill_curve': 0.1,
        'movement_agility': 0.1
    },
    'central_midfielder': {
        'passing': 0.1,
        'mentality_vision': 0.1,
        'skill_ball_control': 0.1,
        'attacking_short_passing': 0.1,
        'mentality_composure': 0.1,
        'defending_interceptions': 0.1,
        'movement_reactions': 0.1,
        'defending_standing_tackle': 0.1,
        'skill_long_passing': 0.1,
        'power_stamina': 0.1
    },
    'wide_midfielder': {
        'dribbling': 0.1,
        'attacking_crossing': 0.1,
        'skill_ball_control': 0.1,
        'pace': 0.1,
        'passing': 0.1,
        'movement_acceleration': 0.1,
        'attacking_finishing': 0.1,
        'power_stamina': 0.1,
        'movement_balance': 0.1,
        'mentality_positioning': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'skill_long_passing': 0.1,
        'mentality_vision': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'skill_ball_control': 0.1,
        'power_stamina': 0.1,
        'mentality_composure': 0.1,
        'passing': 0.1
    },
    'full_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'pace': 0.1,
        'movement_sprint_speed': 0.1,
        'passing': 0.1,
        'movement_balance': 0.1,
        'attacking_short_passing': 0.1,
        'defending_marking_awareness': 0.1,
        'power_stamina': 0.1,
        'skill_ball_control': 0.1
    },
    'wing_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'pace': 0.1,
        'passing': 0.1,
        'movement_balance': 0.1,
        'power_stamina': 0.1,
        'movement_sprint_speed': 0.1,
        'defending_standing_tackle': 0.1,
        'attacking_short_passing': 0.1,
        'power_strength': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'defending_standing_tackle': 0.1,
        'skill_long_passing': 0.1,
        'mentality_composure': 0.1,
        'defending_interceptions': 0.1,
        'power_strength': 0.1,
        'attacking_heading_accuracy': 0.1,
        'passing': 0.1,
        'movement_reactions': 0.1,
        'power_jumping': 0.1
    }
}

# Function to calculate the overall score for each player based on weights and attributes
def calculate_player_overall(player, weights):
    overall_score = 0
    for feature, weight in weights.items():
        overall_score += player.get(feature, 0) * weight
    return overall_score

# Function to compute overall scores for each position and add them as new columns to the dataset
def compute_overall_scores_with_columns(data, weights_dict, tactic):
    # Create a copy of the original data to avoid modifying it directly
    data_with_overall = data.copy()
    
    # For each position, calculate the overall score and add it as a new column
    for position, weights in weights_dict.items():
        data_with_overall[f'{tactic}_{position}'] = data.apply(lambda player: calculate_player_overall(player, weights), axis=1)
    
    return data_with_overall

# Calculate overall scores and add them as new columns to the dataset
data_with_overall_scores = compute_overall_scores_with_columns(data, weights_dict, tactic="PossessionPlay")
data = data_with_overall_scores

# %% [markdown]
# # Counter Attack

# %%
# Define the weights for each position in counter-attack with 0.1 weight for each feature
weights_dict_counter_attack = {
    'striker': {
        'attacking_finishing': 0.1,
        'pace': 0.1,
        'movement_sprint_speed': 0.1,
        'skill_dribbling': 0.1,
        'movement_reactions': 0.1,
        'power_shot_power': 0.1,
        'attacking_heading_accuracy': 0.1,
        'attacking_positioning': 0.1,
        'skill_ball_control': 0.1,
        'attacking_volleys': 0.1
    },
    'center_forward': {
        'pace': 0.1,
        'skill_dribbling': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'attacking_positioning': 0.1,
        'movement_sprint_speed': 0.1,
        'power_shot_power': 0.1,
        'attacking_short_passing': 0.1,
        'skill_ball_control': 0.1,
        'power_long_shots': 0.1
    },
    'winger': {
        'pace': 0.1,
        'movement_sprint_speed': 0.1,
        'skill_dribbling': 0.1,
        'attacking_finishing': 0.1,
        'attacking_short_passing': 0.1,
        'attacking_crossing': 0.1,
        'movement_acceleration': 0.1,
        'skill_ball_control': 0.1,
        'movement_reactions': 0.1,
        'power_stamina': 0.1
    },
    'attacking_midfielder': {
        'mentality_vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_long_passing': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'movement_sprint_speed': 0.1,
        'skill_dribbling': 0.1,
        'pace': 0.1,
        'skill_ball_control': 0.1,
        'mentality_composure': 0.1
    },
    'central_midfielder': {
        'mentality_vision': 0.1,
        'passing': 0.1,
        'movement_reactions': 0.1,
        'skill_long_passing': 0.1,
        'attacking_short_passing': 0.1,
        'movement_sprint_speed': 0.1,
        'power_stamina': 0.1,
        'attacking_finishing': 0.1,
        'skill_ball_control': 0.1,
        'mentality_positioning': 0.1
    },
    'wide_midfielder': {
        'pace': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_short_passing': 0.1,
        'attacking_crossing': 0.1,
        'movement_acceleration': 0.1,
        'power_stamina': 0.1,
        'attacking_finishing': 0.1,
        'skill_ball_control': 0.1,
        'movement_reactions': 0.1,
        'skill_dribbling': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'skill_long_passing': 0.1,
        'movement_reactions': 0.1,
        'power_strength': 0.1,
        'skill_ball_control': 0.1,
        'movement_sprint_speed': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'power_stamina': 0.1,
        'passing': 0.1
    },
    'full_back': {
        'pace': 0.1,
        'attacking_crossing': 0.1,
        'movement_sprint_speed': 0.1,
        'skill_dribbling': 0.1,
        'power_stamina': 0.1,
        'movement_acceleration': 0.1,
        'defending_marking_awareness': 0.1,
        'attacking_short_passing': 0.1,
        'defending_standing_tackle': 0.1,
        'passing': 0.1
    },
    'wing_back': {
        'pace': 0.1,
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'movement_sprint_speed': 0.1,
        'power_stamina': 0.1,
        'attacking_short_passing': 0.1,
        'movement_acceleration': 0.1,
        'defending_standing_tackle': 0.1,
        'power_strength': 0.1,
        'skill_ball_control': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'defending_standing_tackle': 0.1,
        'movement_sprint_speed': 0.1,
        'power_strength': 0.1,
        'attacking_heading_accuracy': 0.1,
        'movement_reactions': 0.1,
        'defending_interceptions': 0.1,
        'power_jumping': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1
    }
}

# Use the same function to calculate the overall scores for counter-attack tactics
data = compute_overall_scores_with_columns(data, weights_dict_counter_attack, tactic='CounterAttack')

# %% [markdown]
# # High Press

# %%
# Define the weights for each position in high press with 0.1 weight for each feature
weights_dict_high_press = {
    'striker': {
        'pace': 0.1,
        'movement_acceleration': 0.1,
        'pressing_aggression': 0.1,
        'skill_dribbling': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'stamina': 0.1,
        'power_strength': 0.1,
        'attacking_positioning': 0.1,
        'mentality_aggression': 0.1
    },
    'center_forward': {
        'pace': 0.1,
        'pressing_aggression': 0.1,
        'movement_reactions': 0.1,
        'attacking_finishing': 0.1,
        'attacking_positioning': 0.1,
        'movement_acceleration': 0.1,
        'stamina': 0.1,
        'power_strength': 0.1,
        'mentality_composure': 0.1,
        'skill_dribbling': 0.1
    },
    'winger': {
        'pressing_aggression': 0.1,
        'movement_acceleration': 0.1,
        'pace': 0.1,
        'skill_dribbling': 0.1,
        'attacking_short_passing': 0.1,
        'stamina': 0.1,
        'power_strength': 0.1,
        'mentality_composure': 0.1,
        'attacking_crossing': 0.1,
        'movement_reactions': 0.1
    },
    'attacking_midfielder': {
        'mentality_vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_long_passing': 0.1,
        'movement_reactions': 0.1,
        'pressing_aggression': 0.1,
        'movement_acceleration': 0.1,
        'stamina': 0.1,
        'power_strength': 0.1,
        'mentality_vision': 0.1,
        'attacking_finishing': 0.1
    },
    'central_midfielder': {
        'passing': 0.1,
        'vision': 0.1,
        'pressing_aggression': 0.1,
        'movement_reactions': 0.1,
        'defending_interceptions': 0.1,
        'stamina': 0.1,
        'power_strength': 0.1,
        'attacking_short_passing': 0.1,
        'skill_ball_control': 0.1,
        'mentality_composure': 0.1
    },
    'wide_midfielder': {
        'pace': 0.1,
        'pressing_aggression': 0.1,
        'movement_acceleration': 0.1,
        'stamina': 0.1,
        'attacking_short_passing': 0.1,
        'skill_ball_control': 0.1,
        'defending_interceptions': 0.1,
        'attacking_crossing': 0.1,
        'mentality_vision': 0.1,
        'power_strength': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'pressing_aggression': 0.1,
        'stamina': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'passing': 0.1,
        'movement_reactions': 0.1,
        'power_strength': 0.1,
        'skill_long_passing': 0.1
    },
    'full_back': {
        'pace': 0.1,
        'pressing_aggression': 0.1,
        'movement_acceleration': 0.1,
        'power_strength': 0.1,
        'stamina': 0.1,
        'defending_marking_awareness': 0.1,
        'attacking_short_passing': 0.1,
        'defending_standing_tackle': 0.1,
        'skill_ball_control': 0.1,
        'mentality_positioning': 0.1
    },
    'wing_back': {
        'pressing_aggression': 0.1,
        'pace': 0.1,
        'movement_acceleration': 0.1,
        'power_strength': 0.1,
        'stamina': 0.1,
        'defending_marking_awareness': 0.1,
        'defending_standing_tackle': 0.1,
        'attacking_short_passing': 0.1,
        'mentality_vision': 0.1,
        'skill_dribbling': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'pressing_aggression': 0.1,
        'defending_standing_tackle': 0.1,
        'power_strength': 0.1,
        'stamina': 0.1,
        'heading_accuracy': 0.1,
        'movement_reactions': 0.1,
        'defending_interceptions': 0.1,
        'power_jumping': 0.1,
        'skill_long_passing': 0.1
    }
}

# Use the same function to calculate the overall scores for high press tactics
data = compute_overall_scores_with_columns(data, weights_dict_high_press, tactic='HighPress')

# %% [markdown]
# # Direct Play

# %%
# Define the weights for each position in direct play with 0.1 weight for each feature
weights_dict_direct_play = {
    'striker': {
        'attacking_finishing': 0.1,
        'attacking_heading_accuracy': 0.1,
        'power_strength': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_positioning': 0.1,
        'attacking_volleys': 0.1,
        'skill_long_passing': 0.1,
        'attacking_reactions': 0.1,
        'attacking_heading_accuracy': 0.1,
        'power_shot_power': 0.1
    },
    'center_forward': {
        'attacking_finishing': 0.1,
        'skill_long_passing': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_positioning': 0.1,
        'aerial_ability': 0.1,
        'attacking_short_passing': 0.1,
        'power_strength': 0.1,
        'attacking_heading_accuracy': 0.1,
        'skill_ball_control': 0.1,
        'attacking_reactions': 0.1
    },
    'winger': {
        'pace': 0.1,
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'power_strength': 0.1,
        'attacking_short_passing': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'power_stamina': 0.1,
        'attacking_volleys': 0.1
    },
    'attacking_midfielder': {
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_long_passing': 0.1,
        'power_strength': 0.1,
        'attacking_positioning': 0.1,
        'movement_reactions': 0.1,
        'attacking_finishing': 0.1,
        'attacking_volleys': 0.1,
        'attacking_heading_accuracy': 0.1,
        'skill_ball_control': 0.1
    },
    'central_midfielder': {
        'vision': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'power_strength': 0.1,
        'attacking_short_passing': 0.1,
        'attacking_reactions': 0.1,
        'defending_interceptions': 0.1,
        'attacking_finishing': 0.1,
        'stamina': 0.1,
        'movement_sprint_speed': 0.1
    },
    'wide_midfielder': {
        'attacking_crossing': 0.1,
        'attacking_short_passing': 0.1,
        'skill_dribbling': 0.1,
        'power_stamina': 0.1,
        'pace': 0.1,
        'movement_reactions': 0.1,
        'power_strength': 0.1,
        'attacking_heading_accuracy': 0.1,
        'attacking_finishing': 0.1,
        'skill_ball_control': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'skill_long_passing': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'power_stamina': 0.1,
        'attacking_short_passing': 0.1,
        'vision': 0.1,
        'movement_reactions': 0.1,
        'aerial_ability': 0.1
    },
    'full_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'attacking_short_passing': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'attacking_positioning': 0.1,
        'power_stamina': 0.1,
        'movement_reactions': 0.1,
        'pace': 0.1
    },
    'wing_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'attacking_short_passing': 0.1,
        'power_strength': 0.1,
        'attacking_positioning': 0.1,
        'power_stamina': 0.1,
        'defending_standing_tackle': 0.1,
        'attacking_volleys': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_reactions': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'aerial_ability': 0.1,
        'power_jumping': 0.1,
        'skill_long_passing': 0.1,
        'defending_interceptions': 0.1,
        'movement_reactions': 0.1,
        'passing': 0.1,
        'power_stamina': 0.1
    }
}

# Use the same function to calculate the overall scores for direct play tactics
data = compute_overall_scores_with_columns(data, weights_dict_direct_play, tactic='DirectPlay')

# %% [markdown]
# # Wing Play

# %%
# Define the weights for each position in wing play with 0.1 weight for each feature
weights_dict_wing_play = {
    'striker': {
        'attacking_finishing': 0.1,
        'heading_accuracy': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_positioning': 0.1,
        'skill_ball_control': 0.1,
        'power_shot_power': 0.1,
        'attacking_reactions': 0.1,
        'skill_dribbling': 0.1,
        'power_strength': 0.1,
        'attacking_volleys': 0.1
    },
    'center_forward': {
        'attacking_finishing': 0.1,
        'skill_ball_control': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_short_passing': 0.1,
        'heading_accuracy': 0.1,
        'skill_dribbling': 0.1,
        'attacking_positioning': 0.1,
        'power_strength': 0.1,
        'attacking_reactions': 0.1,
        'power_shot_power': 0.1
    },
    'winger': {
        'pace': 0.1,
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'movement_acceleration': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'power_strength': 0.1,
        'attacking_volleys': 0.1
    },
    'attacking_midfielder': {
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_ball_control': 0.1,
        'attacking_positioning': 0.1,
        'movement_reactions': 0.1,
        'attacking_finishing': 0.1,
        'attacking_volleys': 0.1,
        'skill_long_passing': 0.1,
        'power_strength': 0.1,
        'attacking_crossing': 0.1
    },
    'central_midfielder': {
        'vision': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'defending_interceptions': 0.1,
        'movement_reactions': 0.1,
        'attacking_positioning': 0.1,
        'attacking_finishing': 0.1,
        'power_strength': 0.1
    },
    'wide_midfielder': {
        'pace': 0.1,
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'power_stamina': 0.1,
        'attacking_short_passing': 0.1,
        'movement_acceleration': 0.1,
        'power_strength': 0.1,
        'movement_reactions': 0.1,
        'attacking_finishing': 0.1,
        'vision': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'defending_marking_awareness': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'movement_reactions': 0.1,
        'power_stamina': 0.1,
        'attacking_short_passing': 0.1,
        'defending_interceptions': 0.1
    },
    'full_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'pace': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'movement_acceleration': 0.1,
        'attacking_positioning': 0.1
    },
    'wing_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'pace': 0.1,
        'movement_acceleration': 0.1,
        'power_stamina': 0.1,
        'attacking_short_passing': 0.1,
        'defending_standing_tackle': 0.1,
        'power_strength': 0.1,
        'attacking_positioning': 0.1,
        'movement_reactions': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'heading_accuracy': 0.1,
        'power_jumping': 0.1,
        'defending_interceptions': 0.1,
        'movement_reactions': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'power_stamina': 0.1
    }
}

# Use the same function to calculate the overall scores for wing play tactics
data = compute_overall_scores_with_columns(data, weights_dict_wing_play, tactic='WingPlay')

# %% [markdown]
# # Set Piece

# %%
# Define the weights for each position in set piece focus with 0.1 weight for each feature
weights_dict_set_piece_focus = {
    'striker': {
        'attacking_finishing': 0.1,
        'heading_accuracy': 0.1,
        'attacking_volleys': 0.1,
        'power_shot_power': 0.1,
        'attacking_positioning': 0.1,
        'skill_fk_accuracy': 0.1,
        'power_strength': 0.1,
        'skill_ball_control': 0.1,
        'aerial_ability': 0.1,
        'attacking_reactions': 0.1
    },
    'center_forward': {
        'attacking_finishing': 0.1,
        'heading_accuracy': 0.1,
        'attacking_volleys': 0.1,
        'power_shot_power': 0.1,
        'skill_fk_accuracy': 0.1,
        'attacking_positioning': 0.1,
        'skill_ball_control': 0.1,
        'power_strength': 0.1,
        'attacking_reactions': 0.1,
        'vision': 0.1
    },
    'winger': {
        'attacking_crossing': 0.1,
        'skill_fk_accuracy': 0.1,
        'skill_dribbling': 0.1,
        'pace': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'attacking_finishing': 0.1,
        'attacking_volleys': 0.1,
        'power_strength': 0.1,
        'movement_acceleration': 0.1
    },
    'attacking_midfielder': {
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_fk_accuracy': 0.1,
        'power_shot_power': 0.1,
        'attacking_positioning': 0.1,
        'attacking_finishing': 0.1,
        'attacking_volleys': 0.1,
        'power_strength': 0.1,
        'movement_reactions': 0.1,
        'skill_ball_control': 0.1
    },
    'central_midfielder': {
        'vision': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'defending_interceptions': 0.1,
        'power_strength': 0.1,
        'attacking_volleys': 0.1,
        'attacking_finishing': 0.1,
        'skill_fk_accuracy': 0.1
    },
    'wide_midfielder': {
        'attacking_crossing': 0.1,
        'attacking_short_passing': 0.1,
        'skill_fk_accuracy': 0.1,
        'power_stamina': 0.1,
        'pace': 0.1,
        'movement_acceleration': 0.1,
        'power_strength': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'vision': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'defending_marking_awareness': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'power_stamina': 0.1,
        'skill_long_passing': 0.1,
        'passing': 0.1,
        'movement_reactions': 0.1,
        'attacking_short_passing': 0.1,
        'heading_accuracy': 0.1
    },
    'full_back': {
        'attacking_crossing': 0.1,
        'skill_fk_accuracy': 0.1,
        'skill_dribbling': 0.1,
        'power_strength': 0.1,
        'power_stamina': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'movement_acceleration': 0.1,
        'passing': 0.1,
        'heading_accuracy': 0.1
    },
    'wing_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'power_strength': 0.1,
        'power_stamina': 0.1,
        'attacking_short_passing': 0.1,
        'movement_acceleration': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'skill_fk_accuracy': 0.1,
        'movement_reactions': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'heading_accuracy': 0.1,
        'defending_standing_tackle': 0.1,
        'power_strength': 0.1,
        'power_jumping': 0.1,
        'defending_interceptions': 0.1,
        'power_stamina': 0.1,
        'aerial_ability': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1
    }
}

# Use the same function to calculate the overall scores for set piece focus tactics
data = compute_overall_scores_with_columns(data, weights_dict_set_piece_focus, tactic='SetPieceFocus')

# %% [markdown]
# # Creative Playmaking

# %%
# Define the weights for each position in creative playmaking with 0.1 weight for each feature
weights_dict_creative_playmaking = {
    'striker': {
        'attacking_finishing': 0.1,
        'attacking_positioning': 0.1,
        'skill_dribbling': 0.1,
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_ball_control': 0.1,
        'attacking_volleys': 0.1,
        'composure': 0.1,
        'power_long_shots': 0.1,
        'movement_reactions': 0.1
    },
    'center_forward': {
        'attacking_finishing': 0.1,
        'vision': 0.1,
        'skill_dribbling': 0.1,
        'attacking_short_passing': 0.1,
        'attacking_positioning': 0.1,
        'movement_balance': 0.1,
        'power_shot_power': 0.1,
        'skill_ball_control': 0.1,
        'attacking_reactions': 0.1,
        'passing': 0.1
    },
    'winger': {
        'vision': 0.1,
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'movement_acceleration': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'attacking_finishing': 0.1,
        'attacking_volleys': 0.1,
        'attacking_reactions': 0.1,
        'pace': 0.1
    },
    'attacking_midfielder': {
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_long_passing': 0.1,
        'attacking_positioning': 0.1,
        'skill_dribbling': 0.1,
        'power_stamina': 0.1,
        'movement_reactions': 0.1,
        'attacking_finishing': 0.1,
        'skill_ball_control': 0.1,
        'composure': 0.1
    },
    'central_midfielder': {
        'vision': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'defending_interceptions': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'skill_ball_control': 0.1,
        'composure': 0.1
    },
    'wide_midfielder': {
        'attacking_crossing': 0.1,
        'attacking_short_passing': 0.1,
        'skill_dribbling': 0.1,
        'vision': 0.1,
        'movement_reactions': 0.1,
        'power_stamina': 0.1,
        'attacking_finishing': 0.1,
        'movement_balance': 0.1,
        'attacking_volleys': 0.1,
        'skill_ball_control': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'vision': 0.1,
        'passing': 0.1,
        'power_strength': 0.1,
        'defending_marking_awareness': 0.1,
        'skill_long_passing': 0.1,
        'attacking_short_passing': 0.1,
        'movement_reactions': 0.1,
        'skill_ball_control': 0.1,
        'composure': 0.1
    },
    'full_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'attacking_short_passing': 0.1,
        'vision': 0.1,
        'power_stamina': 0.1,
        'defending_marking_awareness': 0.1,
        'defending_standing_tackle': 0.1,
        'movement_reactions': 0.1,
        'skill_ball_control': 0.1,
        'attacking_positioning': 0.1
    },
    'wing_back': {
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'movement_acceleration': 0.1,
        'power_stamina': 0.1,
        'skill_ball_control': 0.1,
        'movement_reactions': 0.1,
        'attacking_finishing': 0.1,
        'power_strength': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'skill_long_passing': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'heading_accuracy': 0.1,
        'movement_reactions': 0.1,
        'passing': 0.1,
        'attacking_positioning': 0.1,
        'power_stamina': 0.1,
        'aerial_ability': 0.1
    }
}

# Use the same function to calculate the overall scores for creative playmaking tactics
data = compute_overall_scores_with_columns(data, weights_dict_creative_playmaking, tactic='CreativePlaymaking')

# %% [markdown]
# # Playing Out From The Back

# %%
# Define the weights for each position in Playing Out from the Back with 0.1 weight for each feature
weights_dict_playing_out_back = {
    'striker': {
        'attacking_positioning': 0.1,
        'attacking_short_passing': 0.1,
        'vision': 0.1,
        'skill_dribbling': 0.1,
        'attacking_finishing': 0.1,
        'power_strength': 0.1,
        'movement_reactions': 0.1,
        'skill_ball_control': 0.1,
        'composure': 0.1,
        'movement_sprint_speed': 0.1
    },
    'center_forward': {
        'attacking_positioning': 0.1,
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'movement_balance': 0.1,
        'skill_ball_control': 0.1,
        'skill_dribbling': 0.1,
        'power_shot_power': 0.1,
        'movement_reactions': 0.1,
        'attacking_finishing': 0.1,
        'attacking_crossing': 0.1
    },
    'winger': {
        'vision': 0.1,
        'attacking_crossing': 0.1,
        'skill_dribbling': 0.1,
        'movement_acceleration': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'skill_ball_control': 0.1,
        'attacking_finishing': 0.1,
        'movement_reactions': 0.1,
        'attacking_positioning': 0.1
    },
    'attacking_midfielder': {
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_long_passing': 0.1,
        'attacking_positioning': 0.1,
        'skill_dribbling': 0.1,
        'movement_reactions': 0.1,
        'skill_ball_control': 0.1,
        'composure': 0.1,
        'attacking_finishing': 0.1,
        'power_strength': 0.1
    },
    'central_midfielder': {
        'vision': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'defending_interceptions': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'skill_ball_control': 0.1,
        'composure': 0.1,
        'defending_marking_awareness': 0.1,
        'movement_reactions': 0.1
    },
    'wide_midfielder': {
        'vision': 0.1,
        'attacking_crossing': 0.1,
        'attacking_short_passing': 0.1,
        'skill_dribbling': 0.1,
        'movement_reactions': 0.1,
        'power_stamina': 0.1,
        'skill_ball_control': 0.1,
        'movement_balance': 0.1,
        'attacking_positioning': 0.1,
        'attacking_finishing': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'vision': 0.1,
        'passing': 0.1,
        'defending_marking_awareness': 0.1,
        'skill_long_passing': 0.1,
        'defending_standing_tackle': 0.1,
        'skill_ball_control': 0.1,
        'movement_reactions': 0.1,
        'power_strength': 0.1,
        'composure': 0.1
    },
    'full_back': {
        'attacking_crossing': 0.1,
        'attacking_short_passing': 0.1,
        'skill_dribbling': 0.1,
        'vision': 0.1,
        'defending_marking_awareness': 0.1,
        'defending_standing_tackle': 0.1,
        'skill_ball_control': 0.1,
        'power_stamina': 0.1,
        'movement_acceleration': 0.1,
        'attacking_positioning': 0.1
    },
    'wing_back': {
        'attacking_crossing': 0.1,
        'attacking_short_passing': 0.1,
        'skill_dribbling': 0.1,
        'movement_acceleration': 0.1,
        'power_stamina': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_marking_awareness': 0.1,
        'skill_ball_control': 0.1,
        'vision': 0.1,
        'power_strength': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'heading_accuracy': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'defending_interceptions': 0.1,
        'aerial_ability': 0.1,
        'power_stamina': 0.1,
        'movement_reactions': 0.1
    }
}

# Use the same function to calculate the overall scores for playing out from the back tactics
data = compute_overall_scores_with_columns(data, weights_dict_playing_out_back, tactic='PlayingOutFromTheBack')

# %% [markdown]
# # Low Block

# %%
# Define the weights for each position in Low Block with 0.1 weight for each feature
weights_dict_low_block = {
    'striker': {
        'defensive_positioning': 0.1,
        'attacking_positioning': 0.1,
        'stamina': 0.1,
        'pressing_aggression': 0.1,
        'power_strength': 0.1,
        'attacking_reactions': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_short_passing': 0.1,
        'vision': 0.1,
        'defensive_work_rate': 0.1
    },
    'center_forward': {
        'attacking_positioning': 0.1,
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'defensive_positioning': 0.1,
        'movement_balance': 0.1,
        'power_strength': 0.1,
        'attacking_reactions': 0.1,
        'defensive_interceptions': 0.1,
        'movement_sprint_speed': 0.1,
        'stamina': 0.1
    },
    'winger': {
        'defensive_positioning': 0.1,
        'attacking_short_passing': 0.1,
        'pressing_aggression': 0.1,
        'vision': 0.1,
        'power_stamina': 0.1,
        'movement_reactions': 0.1,
        'defensive_work_rate': 0.1,
        'movement_acceleration': 0.1,
        'attacking_finishing': 0.1,
        'skill_dribbling': 0.1
    },
    'attacking_midfielder': {
        'vision': 0.1,
        'defensive_interceptions': 0.1,
        'attacking_short_passing': 0.1,
        'pressing_aggression': 0.1,
        'power_strength': 0.1,
        'defensive_positioning': 0.1,
        'stamina': 0.1,
        'movement_reactions': 0.1,
        'defensive_work_rate': 0.1,
        'attacking_finishing': 0.1
    },
    'central_midfielder': {
        'vision': 0.1,
        'defensive_interceptions': 0.1,
        'defending_marking_awareness': 0.1,
        'stamina': 0.1,
        'pressing_aggression': 0.1,
        'skill_long_passing': 0.1,
        'attacking_short_passing': 0.1,
        'defensive_work_rate': 0.1,
        'power_strength': 0.1,
        'defensive_positioning': 0.1
    },
    'wide_midfielder': {
        'defensive_positioning': 0.1,
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'pressing_aggression': 0.1,
        'power_stamina': 0.1,
        'defensive_work_rate': 0.1,
        'movement_reactions': 0.1,
        'attacking_crossing': 0.1,
        'defensive_interceptions': 0.1,
        'movement_sprint_speed': 0.1
    },
    'defensive_midfielder': {
        'defending_marking_awareness': 0.1,
        'defensive_positioning': 0.1,
        'defensive_interceptions': 0.1,
        'pressing_aggression': 0.1,
        'stamina': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'vision': 0.1,
        'skill_long_passing': 0.1,
        'attacking_short_passing': 0.1
    },
    'full_back': {
        'defending_marking_awareness': 0.1,
        'defensive_positioning': 0.1,
        'defensive_interceptions': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'pressing_aggression': 0.1,
        'movement_acceleration': 0.1,
        'defensive_work_rate': 0.1,
        'defending_standing_tackle': 0.1,
        'power_strength': 0.1
    },
    'wing_back': {
        'defending_marking_awareness': 0.1,
        'attacking_short_passing': 0.1,
        'defensive_positioning': 0.1,
        'defensive_interceptions': 0.1,
        'pressing_aggression': 0.1,
        'power_stamina': 0.1,
        'defending_standing_tackle': 0.1,
        'skill_dribbling': 0.1,
        'movement_acceleration': 0.1,
        'vision': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'defensive_positioning': 0.1,
        'defensive_interceptions': 0.1,
        'pressing_aggression': 0.1,
        'power_strength': 0.1,
        'defending_standing_tackle': 0.1,
        'heading_accuracy': 0.1,
        'power_stamina': 0.1,
        'power_jumping': 0.1,
        'vision': 0.1
    }
}

# Use the same function to calculate the overall scores for low block tactics
data = compute_overall_scores_with_columns(data, weights_dict_low_block, tactic='LowBlock')

# %% [markdown]
# # High Defensive Line

# %%
# Define the weights for each position in High Defensive Line with 0.1 weight for each feature
weights_dict_high_defensive_line = {
    'striker': {
        'attacking_positioning': 0.1,
        'movement_sprint_speed': 0.1,
        'pressing_aggression': 0.1,
        'attacking_finishing': 0.1,
        'skill_dribbling': 0.1,
        'vision': 0.1,
        'power_strength': 0.1,
        'movement_reactions': 0.1,
        'power_stamina': 0.1,
        'attacking_short_passing': 0.1
    },
    'center_forward': {
        'attacking_positioning': 0.1,
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'movement_sprint_speed': 0.1,
        'pressing_aggression': 0.1,
        'skill_dribbling': 0.1,
        'movement_reactions': 0.1,
        'power_strength': 0.1,
        'attacking_finishing': 0.1,
        'attacking_crossing': 0.1
    },
    'winger': {
        'attacking_crossing': 0.1,
        'pressing_aggression': 0.1,
        'vision': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_short_passing': 0.1,
        'skill_dribbling': 0.1,
        'power_stamina': 0.1,
        'attacking_positioning': 0.1,
        'movement_acceleration': 0.1,
        'attacking_finishing': 0.1
    },
    'attacking_midfielder': {
        'vision': 0.1,
        'attacking_short_passing': 0.1,
        'skill_long_passing': 0.1,
        'movement_reactions': 0.1,
        'attacking_positioning': 0.1,
        'pressing_aggression': 0.1,
        'movement_sprint_speed': 0.1,
        'power_strength': 0.1,
        'skill_ball_control': 0.1,
        'composure': 0.1
    },
    'central_midfielder': {
        'vision': 0.1,
        'passing': 0.1,
        'skill_long_passing': 0.1,
        'attacking_short_passing': 0.1,
        'power_stamina': 0.1,
        'movement_reactions': 0.1,
        'defending_interceptions': 0.1,
        'pressing_aggression': 0.1,
        'composure': 0.1,
        'defending_marking_awareness': 0.1
    },
    'wide_midfielder': {
        'attacking_crossing': 0.1,
        'pressing_aggression': 0.1,
        'vision': 0.1,
        'movement_sprint_speed': 0.1,
        'attacking_short_passing': 0.1,
        'skill_dribbling': 0.1,
        'power_stamina': 0.1,
        'movement_reactions': 0.1,
        'attacking_positioning': 0.1,
        'skill_ball_control': 0.1
    },
    'defensive_midfielder': {
        'defending_interceptions': 0.1,
        'vision': 0.1,
        'passing': 0.1,
        'defending_marking_awareness': 0.1,
        'skill_long_passing': 0.1,
        'defending_standing_tackle': 0.1,
        'power_strength': 0.1,
        'movement_reactions': 0.1,
        'pressing_aggression': 0.1,
        'composure': 0.1
    },
    'full_back': {
        'defending_marking_awareness': 0.1,
        'defending_interceptions': 0.1,
        'attacking_crossing': 0.1,
        'pressing_aggression': 0.1,
        'movement_sprint_speed': 0.1,
        'power_stamina': 0.1,
        'defending_standing_tackle': 0.1,
        'skill_dribbling': 0.1,
        'movement_acceleration': 0.1,
        'attacking_short_passing': 0.1
    },
    'wing_back': {
        'defending_marking_awareness': 0.1,
        'defending_interceptions': 0.1,
        'attacking_crossing': 0.1,
        'movement_sprint_speed': 0.1,
        'power_stamina': 0.1,
        'attacking_short_passing': 0.1,
        'skill_dribbling': 0.1,
        'defending_standing_tackle': 0.1,
        'vision': 0.1,
        'power_strength': 0.1
    },
    'center_back': {
        'defending_marking_awareness': 0.1,
        'movement_sprint_speed': 0.1,
        'defending_interceptions': 0.1,
        'heading_accuracy': 0.1,
        'pressing_aggression': 0.1,
        'defending_standing_tackle': 0.1,
        'power_strength': 0.1,
        'vision': 0.1,
        'power_stamina': 0.1,
        'aerial_ability': 0.1
    }
}

# Use the same function to calculate the overall scores for High Defensive Line tactics
data = compute_overall_scores_with_columns(data, weights_dict_high_defensive_line, tactic='HighDefensiveLine')

# %%
data.head()
# Out:
#    fifa_version    short_name                       long_name  \
# 0          24.0     K. Mbappé            Kylian Mbappé Lottin
# 1          24.0    E. Haaland            Erling Braut Haaland
# 2          24.0  K. De Bruyne                 Kevin De Bruyne
# 3          24.0      L. Messi  Lionel Andrés Messi Cuccittini
# 4          24.0    K. Benzema                   Karim Benzema
#
#   player_positions  overall  potential  age            club_name  \
# 0           ST, LW       91         94   24  Paris Saint Germain
# 1               ST       91         94   22      Manchester City
# 2          CM, CAM       91         91   32      Manchester City
# 3          CF, CAM       90         90   36          Inter Miami
# 4           CF, ST       90         90   35           Al Ittihad
#
#            league_name club_position  pace  shooting  passing  dribbling  \
# 0              Ligue 1            LW  97.0      90.0     80.0       92.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180021 entries, 0 to 180020
# Columns: 182 entries, fifa_version to HighDefensiveLine_center_back
# dtypes: float64(109), int64(36), object(37)
# memory usage: 250.0+ MB

# %%
import pandas as pd

# Assuming your dataset is loaded into a DataFrame named df
# For example, df = pd.read_csv('your_dataset.csv')

# Filter the dataset for fifa_version = 24.0
filtered_df = data[data['fifa_version'] == 24.0]

data = filtered_df

# Optionally, save the random samples to a new CSV file
# random_samples.to_csv('random_samples.csv', index=False)

# %%
import pandas as pd

# Assuming df is your DataFrame
columns_to_drop = [
    'fifa_version', 'potential', 'age', 'league_name', 'pace', 'shooting', 'passing',
    'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy',
    'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy',
    'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
    'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
    'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision',
    'mentality_penalties', 'mentality_composure', 'defending_marking_awareness', 'defending_standing_tackle',
    'defending_sliding_tackle', 'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
    'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed', "position_1", "position_2", "position_3", "position_4"
]


# Dropping the columns
data = data.drop(columns=columns_to_drop)

# %%
data.head()
# Out:
#      short_name                       long_name player_positions  overall  \
# 0     K. Mbappé            Kylian Mbappé Lottin           ST, LW       91
# 1    E. Haaland            Erling Braut Haaland               ST       91
# 2  K. De Bruyne                 Kevin De Bruyne          CM, CAM       91
# 3      L. Messi  Lionel Andrés Messi Cuccittini          CF, CAM       90
# 4    K. Benzema                   Karim Benzema           CF, ST       90
#
#              club_name club_position    ls    st    rs  lw  lf  cf  rf  rw  \
# 0  Paris Saint Germain            LW  90+3  90+3  90+3  91  91  91  91  91
# 1      Manchester City            ST  90+3  90+3  90+3  82  86  86  86  82
# 2      Manchester City           SUB  83+3  83+3  83+3  87  88  88  88  87
# 3          Inter Miami            RF  85+3  85+3  85+3  90  89  89  89  90
# 4           Al Ittihad            RS  88+2  88+2  88+2  86  89  89  89  86
#
# ...

# %%
data.to_csv("Players 2024.csv")
